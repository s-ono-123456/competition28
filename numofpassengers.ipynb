# %%
import json
import pandas as pd
from pandas import json_normalize

# %%
json_open = open('reference/S12-20_NumberOfPassengers.geojson', 'r')

# %%
json_load = json.load(json_open)

# %%
df = json_normalize(json_load['features'][0]['properties'])
for i in range(1, len(json_load['features'])):
    df_tmp = json_normalize(json_load['features'][i]['properties'])
    df = pd.concat([df, df_tmp])

# %%
df = df.reset_index().drop(['index'], axis=1)

# %%
df.head(2)
# Out:
#   S12_001    S12_002     S12_003  S12_004  S12_005  S12_006  S12_007 S12_008  \
# 0     二月田     九州旅客鉄道       指宿枕崎線       11        2        1        3    None
# 1      古島  沖縄都市モノレール  沖縄都市モノレール線       23        5        1        1    None
#
#    S12_009  S12_010  ...  S12_032 S12_033  S12_034  S12_035  S12_036 S12_037  \
# 0        0        1  ...     None       0        1        1     None     658
# 1     3907        1  ...     None    4819        1        1     None    5086
#
#    S12_038  S12_039  S12_040 S12_041
# 0        1        1     None     690
# 1        1        1     None    5143
#
# [2 rows x 41 columns]

# %%
df.columns
# Out:
# Index(['S12_001', 'S12_002', 'S12_003', 'S12_004', 'S12_005', 'S12_006',
#        'S12_007', 'S12_008', 'S12_009', 'S12_010', 'S12_011', 'S12_012',
#        'S12_013', 'S12_014', 'S12_015', 'S12_016', 'S12_017', 'S12_018',
#        'S12_019', 'S12_020', 'S12_021', 'S12_022', 'S12_023', 'S12_024',
#        'S12_025', 'S12_026', 'S12_027', 'S12_028', 'S12_029', 'S12_030',
#        'S12_031', 'S12_032', 'S12_033', 'S12_034', 'S12_035', 'S12_036',
#        'S12_037', 'S12_038', 'S12_039', 'S12_040', 'S12_041'],
#       dtype='object')

# %%
cols = ['S12_001', 'S12_002', 'S12_003', 'S12_004', 'S12_005', 'S12_038', 'S12_039', 'S12_040', 'S12_041']

# %%
df = df[cols]

# %%
df.columns= ['駅名', '運営会社', '路線名', '鉄道区分', '事業者種別', '重複コード2019', 'データ有無コード2019', '備考2019', '乗降客数2019']

# %%
df.loc[(df['駅名'] == '西武遊園地') & (df['路線名'] == '山口線'), '駅名'] = '西武園ゆうえんち'

# %%
df.loc[(df['駅名'] == '我孫子') & (df['路線名'] == '1号線(御堂筋線)'), '駅名'] = 'あびこ'

# %%
df.to_csv('reference/passengers_old.csv', index=False)

# %%
tmp = df[df['重複コード2019'] == 1]
cols = ['駅名', '運営会社', '路線名', '乗降客数2019']
tmp = tmp[cols]
tmp = tmp.reset_index().drop('index', axis=1)

# %%
samelist = ['ときわ台',  '三条',  '三田',  '三郷',  '中島',  '中津',  '中田',  '丸山',  '九条',  '二軒茶屋',  '井野',  '京橋',  '今池',  '今津',  '今里',  '伊丹',  '伏見',  '住吉',  '元山',  '元町',  '光風台',  '八幡',  '八幡前',  '八田',  '六地蔵',  '別府',  '北山',  '十条',  '南桜井',  '原',  '古市',  '吹上',  '吹田',  '呉服町',  '味美',  '和白',  '国府',  '国際センター',  '土橋',  '城野',  '堀田',  '塚口',  '塩屋',  '大久保',  '大倉山',  '大和田',  '大塚',  '大宮',  '大手町',  '大町',  '大門',  '大阪梅田',  '太田',  '学園前',  '宇治',  '富士見町',  '富田',  '小倉',  '小野',  '尼崎',  '山下',  '山口',  '山崎',  '山本',  '山田',  '岡本',  '嵐山',  '川内',  '市役所前',  '常盤',  '平井',  '平和台',  '平野',  '府中',  '弘明寺',  '御影',  '戸田',  '新川町',  '新栄町',  '新田',  '新町',  '日本橋',  '日比野',  '日進',  '早稲田',  '春日',  '春日井',  '春日野道',  '昭和町',  '朝倉',  '木幡',  '木津',  '末広町',  '本郷',  '東山',  '東山公園',  '柚木',  '栄',  '栄町',  '桜井',  '桜台',  '梅林',  '森下',  '橋本',  '比良',  '池田',  '河原町',  '泉',  '浅草',  '清水',  '牛田',  '玉造',  '琴似',  '瓢箪山',  '田原町',  '白山',  '白石',  '県庁前',  '矢田',  '石田',  '福井',  '福島',  '稲荷町',  '競馬場前',  '筒井',  '緑が丘',  '芦屋',  '花園',  '若林',  '茶山',  '草津',  '萩原',  '藤が丘',  '西宮',  '西院',  '谷山',  '豊川',  '貝塚',  '赤坂',  '追分',  '郡山',  '野田',  '金山',  '長原',  '長沼',  '長浦',  '長田',  '青山',  '高井田',  '高崎',  '高松',  '高田',  '黄檗',  '黒川']

# %%
tmp.loc[(tmp['駅名'] == 'ときわ台') & (tmp['路線名'] == '東上本線'), '駅名'] = 'ときわ台' + '_' + '東京'
tmp.loc[(tmp['駅名'] == 'ときわ台') & (tmp['路線名'] == '妙見線'), '駅名'] = 'ときわ台' + '_' + '大阪'

tmp.loc[(tmp['駅名'] == '三条') & (tmp['路線名'] == '信越線'), '駅名'] = '三条' + '_' + '新潟'
tmp.loc[(tmp['駅名'] == '三条') & (tmp['路線名'] == '琴平線'), '駅名'] = '三条' + '_' + '高松'
tmp.loc[(tmp['駅名'] == '三条') & (tmp['路線名'] == '京阪本線'), '駅名'] = '三条' + '_' + '京都'

tmp.loc[(tmp['駅名'] == '三田') & (tmp['路線名'] == '三田線'), '駅名'] = '三田' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '三田') & (tmp['路線名'] == '福知山線'), '駅名'] = '三田' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '三田') & (tmp['路線名'] == '1号線浅草線'), '駅名'] = '三田' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '三郷') & (tmp['路線名'] == '関西線'), '駅名'] = '三郷' + '_' + '奈良'
tmp.loc[(tmp['駅名'] == '三郷') & (tmp['路線名'] == '武蔵野線'), '駅名'] = '三郷' + '_' + '埼玉'
tmp.loc[(tmp['駅名'] == '三郷') & (tmp['路線名'] == '瀬戸線'), '駅名'] = '三郷' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '中島') & (tmp['路線名'] == '可部線'), '駅名'] = '中島' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '中島') & (tmp['路線名'] == '西名古屋港線'), '駅名'] = '中島' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '中津') & (tmp['路線名'] == '日豊線'), '駅名'] = '中津' + '_' + '大分'
tmp.loc[(tmp['駅名'] == '中津') & (tmp['路線名'] == '神戸線'), '駅名'] = '中津' + '_' + '阪急'
tmp.loc[(tmp['駅名'] == '中津') & (tmp['路線名'] == '1号線(御堂筋線)'), '駅名'] = '中津' + '_' + '大阪メトロ'

tmp.loc[(tmp['駅名'] == '中田') & (tmp['路線名'] == '牟岐線'), '駅名'] = '中田' + '_' + '徳島'
tmp.loc[(tmp['駅名'] == '中田') & (tmp['路線名'] == '1号線'), '駅名'] = '中田' + '_' + '神奈川'

tmp.loc[(tmp['駅名'] == '丸山') & (tmp['路線名'] == '伊奈線'), '駅名'] = '丸山' + '_' + '埼玉'
tmp.loc[(tmp['駅名'] == '丸山') & (tmp['路線名'] == '有馬線'), '駅名'] = '丸山' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '丸山') & (tmp['路線名'] == '伊賀線'), '駅名'] = '丸山' + '_' + '三重'

tmp.loc[(tmp['駅名'] == '九条') & (tmp['路線名'] == '烏丸線'), '駅名'] = '九条' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '九条') & (tmp['路線名'] == '橿原線'), '駅名'] = '九条' + '_' + '奈良'
tmp.loc[(tmp['駅名'] == '九条') & (tmp['路線名'] == '4号線(中央線)'), '駅名'] = '九条' + '_' + '大阪メトロ'
tmp.loc[(tmp['駅名'] == '九条') & (tmp['路線名'] == '阪神なんば線'), '駅名'] = '九条' + '_' + '阪神'

tmp.loc[(tmp['駅名'] == '二軒茶屋') & (tmp['路線名'] == '鞍馬線'), '駅名'] = '二軒茶屋' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '二軒茶屋') & (tmp['路線名'] == '谷山線'), '駅名'] = '二軒茶屋' + '_' + '鹿児島'

tmp.loc[(tmp['駅名'] == '井野') & (tmp['路線名'] == 'ユーカリが丘線'), '駅名'] = '井野' + '_' + '千葉'
tmp.loc[(tmp['駅名'] == '井野') & (tmp['路線名'] == '上越線'), '駅名'] = '井野' + '_' + '群馬'

tmp.loc[(tmp['駅名'] == '京橋') & (tmp['路線名'] == '京阪本線'), '駅名'] = '京橋' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '京橋') & (tmp['路線名'] == '大阪環状線'), '駅名'] = '京橋' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '京橋') & (tmp['路線名'] == '7号線(長堀鶴見緑地線)'), '駅名'] = '京橋' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '京橋') & (tmp['路線名'] == '3号線銀座線'), '駅名'] = '京橋' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '今池') & (tmp['路線名'] == '阪堺線'), '駅名'] = '今池' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '今池') & (tmp['路線名'] == '筑豊電気鉄道線'), '駅名'] = '今池' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '今池') & (tmp['路線名'] == '1号線東山線'), '駅名'] = '今池' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '今津') & (tmp['路線名'] == '今津線'), '駅名'] = '今津' + '_' + '阪急'
tmp.loc[(tmp['駅名'] == '今津') & (tmp['路線名'] == '本線'), '駅名'] = '今津' + '_' + '阪神'

tmp.loc[(tmp['駅名'] == '今里') & (tmp['路線名'] == '大阪線'), '駅名'] = '今里' + '_' + '近鉄'
tmp.loc[(tmp['駅名'] == '今里') & (tmp['路線名'] == '5号線(千日前線)'), '駅名'] = '今里' + '_' + '大阪メトロ'

tmp.loc[(tmp['駅名'] == '伊丹') & (tmp['路線名'] == '伊丹線'), '駅名'] = '伊丹' + '_' + '阪急'
tmp.loc[(tmp['駅名'] == '伊丹') & (tmp['路線名'] == '福知山線'), '駅名'] = '伊丹' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '伏見') & (tmp['路線名'] == '京都線'), '駅名'] = '伏見' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '伏見') & (tmp['路線名'] == '1号線東山線'), '駅名'] = '伏見' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '住吉') & (tmp['路線名'] == '阪堺線'), '駅名'] = '住吉' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '住吉') & (tmp['路線名'] == '本線'), '駅名'] = '住吉' + '_' + '阪神'
tmp.loc[(tmp['駅名'] == '住吉') & (tmp['路線名'] == '六甲アイランド線'), '駅名'] = '住吉' + '_' + 'ＪＲ・六甲ライナー'
tmp.loc[(tmp['駅名'] == '住吉') & (tmp['路線名'] == '東海道線'), '駅名'] = '住吉' + '_' + 'ＪＲ・六甲ライナー'
tmp.loc[(tmp['駅名'] == '住吉') & (tmp['路線名'] == '赤迫支線'), '駅名'] = '住吉' + '_' + '長崎'
tmp.loc[(tmp['駅名'] == '住吉') & (tmp['路線名'] == '11号線半蔵門線'), '駅名'] = '住吉' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '住吉') & (tmp['路線名'] == '10号線新宿線'), '駅名'] = '住吉' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '元山') & (tmp['路線名'] == '長尾線'), '駅名'] = '元山' + '_' + '高松'
tmp.loc[(tmp['駅名'] == '元山') & (tmp['路線名'] == '新京成線'), '駅名'] = '元山' + '_' + '千葉'

tmp.loc[(tmp['駅名'] == '元町') & (tmp['路線名'] == '本線'), '駅名'] = '元町' + '_' + 'ＪＲ'
tmp.loc[(tmp['駅名'] == '元町') & (tmp['路線名'] == '東豊線'), '駅名'] = '元町' + '_' + '札幌'
tmp.loc[(tmp['駅名'] == '元町') & (tmp['路線名'] == '東海道線'), '駅名'] = '元町' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '光風台') & (tmp['路線名'] == '小湊鐵道線'), '駅名'] = '光風台' + '_' + '千葉'
tmp.loc[(tmp['駅名'] == '光風台') & (tmp['路線名'] == '妙見線'), '駅名'] = '光風台' + '_' + '大阪'

tmp.loc[(tmp['駅名'] == '八幡') & (tmp['路線名'] == '鉄道線'), '駅名'] = '八幡' + '_' + '愛知'
tmp.loc[(tmp['駅名'] == '八幡') & (tmp['路線名'] == '鹿児島線'), '駅名'] = '八幡' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '八幡') & (tmp['路線名'] == '豊川線'), '駅名'] = '八幡' + '_' + '静岡'

tmp.loc[(tmp['駅名'] == '八幡前') & (tmp['路線名'] == '鞍馬線'), '駅名'] = '八幡前' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '八幡前') & (tmp['路線名'] == '加太線'), '駅名'] = '八幡前' + '_' + '和歌山'

tmp.loc[(tmp['駅名'] == '八田') & (tmp['路線名'] == '関西線'), '駅名'] = '八田' + '_' + 'ＪＲ'
tmp.loc[(tmp['駅名'] == '八田') & (tmp['路線名'] == '1号線東山線'), '駅名'] = '八田' + '_' + '名古屋市営'

tmp.loc[(tmp['駅名'] == '六地蔵') & (tmp['路線名'] == '宇治線'), '駅名'] = '六地蔵' + '_' + '京阪'
tmp.loc[(tmp['駅名'] == '六地蔵') & (tmp['路線名'] == '東西線'), '駅名'] = '六地蔵' + '_' + '京都市営'
tmp.loc[(tmp['駅名'] == '六地蔵') & (tmp['路線名'] == '奈良線'), '駅名'] = '六地蔵' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '別府') & (tmp['路線名'] == '日豊線'), '駅名'] = '別府' + '_' + '大分'
tmp.loc[(tmp['駅名'] == '別府') & (tmp['路線名'] == '本線'), '駅名'] = '別府' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '別府') & (tmp['路線名'] == '3号線(七隈線)'), '駅名'] = '別府' + '_' + '福岡'

tmp.loc[(tmp['駅名'] == '北山') & (tmp['路線名'] == '烏丸線'), '駅名'] = '北山' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '北山') & (tmp['路線名'] == '真岡線'), '駅名'] = '北山' + '_' + '栃木'
tmp.loc[(tmp['駅名'] == '北山') & (tmp['路線名'] == '伊野線'), '駅名'] = '北山' + '_' + '高知'
tmp.loc[(tmp['駅名'] == '北山') & (tmp['路線名'] == '仙山線'), '駅名'] = '北山' + '_' + '宮城'

tmp.loc[(tmp['駅名'] == '十条') & (tmp['路線名'] == '烏丸線'), '駅名'] = '十条' + '_' + '京都市営'
tmp.loc[(tmp['駅名'] == '十条') & (tmp['路線名'] == '京都線'), '駅名'] = '十条' + '_' + '近鉄'
tmp.loc[(tmp['駅名'] == '十条') & (tmp['路線名'] == '赤羽線（埼京線）'), '駅名'] = '十条' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '南桜井') & (tmp['路線名'] == '野田線'), '駅名'] = '南桜井' + '_' + '埼玉'
tmp.loc[(tmp['駅名'] == '南桜井') & (tmp['路線名'] == '西尾線'), '駅名'] = '南桜井' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '原') & (tmp['路線名'] == '志度線'), '駅名'] = '原' + '_' + '香川'
tmp.loc[(tmp['駅名'] == '原') & (tmp['路線名'] == '東海道線'), '駅名'] = '原' + '_' + '静岡'
tmp.loc[(tmp['駅名'] == '原') & (tmp['路線名'] == '3号線鶴舞線'), '駅名'] = '原' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '古市') & (tmp['路線名'] == '南大阪線'), '駅名'] = '古市' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '古市') & (tmp['路線名'] == '広島新交通1号線'), '駅名'] = '古市' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '古市') & (tmp['路線名'] == '福知山線'), '駅名'] = '古市' + '_' + '兵庫'

tmp.loc[(tmp['駅名'] == '吹上') & (tmp['路線名'] == '高崎線'), '駅名'] = '吹上' + '_' + '埼玉'
tmp.loc[(tmp['駅名'] == '吹上') & (tmp['路線名'] == '6号線桜通線'), '駅名'] = '吹上' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '吹田') & (tmp['路線名'] == '千里線'), '駅名'] = '吹田' + '_' + '阪急'
tmp.loc[(tmp['駅名'] == '吹田') & (tmp['路線名'] == '東海道線'), '駅名'] = '吹田' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '呉服町') & (tmp['路線名'] == '幹線'), '駅名'] = '呉服町' + '_' + '熊本'
tmp.loc[(tmp['駅名'] == '呉服町') & (tmp['路線名'] == '2号線(箱崎線)'), '駅名'] = '呉服町' + '_' + '福岡'

tmp.loc[(tmp['駅名'] == '味美') & (tmp['路線名'] == '城北線'), '駅名'] = '味美' + '_' + '東海交通'
tmp.loc[(tmp['駅名'] == '味美') & (tmp['路線名'] == '小牧線'), '駅名'] = '味美' + '_' + '名鉄'

tmp.loc[(tmp['駅名'] == '和白') & (tmp['路線名'] == '香椎線'), '駅名'] = '和白' + '_' + 'ＪＲ'
tmp.loc[(tmp['駅名'] == '和白') & (tmp['路線名'] == '貝塚線'), '駅名'] = '和白' + '_' + '西鉄'

tmp.loc[(tmp['駅名'] == '国府') & (tmp['路線名'] == '水前寺線'), '駅名'] = '国府' + '_' + '熊本'
tmp.loc[(tmp['駅名'] == '国府') & (tmp['路線名'] == '山陰線'), '駅名'] = '国府' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '国府') & (tmp['路線名'] == '名古屋本線'), '駅名'] = '国府' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '国際センター') & (tmp['路線名'] == '6号線桜通線'), '駅名'] = '国際センター' + '_' + '愛知'
tmp.loc[(tmp['駅名'] == '国際センター') & (tmp['路線名'] == '東西線'), '駅名'] = '国際センター' + '_' + '宮城'

tmp.loc[(tmp['駅名'] == '土橋') & (tmp['路線名'] == '郡中線'), '駅名'] = '土橋' + '_' + '愛媛'
tmp.loc[(tmp['駅名'] == '土橋') & (tmp['路線名'] == '本線'), '駅名'] = '土橋' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '土橋') & (tmp['路線名'] == '三河線'), '駅名'] = '土橋' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '城野') & (tmp['路線名'] == '日豊線'), '駅名'] = '城野' + '_' + 'ＪＲ'
tmp.loc[(tmp['駅名'] == '城野') & (tmp['路線名'] == '小倉線'), '駅名'] = '城野' + '_' + '北九州モノレール'

tmp.loc[(tmp['駅名'] == '堀田') & (tmp['路線名'] == '4号線名城線'), '駅名'] = '堀田' + '_' + '名古屋市営'
tmp.loc[(tmp['駅名'] == '堀田') & (tmp['路線名'] == '名古屋本線'), '駅名'] = '堀田' + '_' + '名鉄'

tmp.loc[(tmp['駅名'] == '塚口') & (tmp['路線名'] == '神戸線'), '駅名'] = '塚口' + '_' + '阪急'
tmp.loc[(tmp['駅名'] == '塚口') & (tmp['路線名'] == '福知山線'), '駅名'] = '塚口' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '塩屋') & (tmp['路線名'] == '志度線'), '駅名'] = '塩屋' + '_' + '高松'
tmp.loc[(tmp['駅名'] == '塩屋') & (tmp['路線名'] == '山陽線'), '駅名'] = '塩屋' + '_' + '兵庫'

tmp.loc[(tmp['駅名'] == '大久保') & (tmp['路線名'] == '京都線'), '駅名'] = '大久保' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '大久保') & (tmp['路線名'] == '山陽線'), '駅名'] = '大久保' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '大久保') & (tmp['路線名'] == '奥羽線'), '駅名'] = '大久保' + '_' + '秋田'
tmp.loc[(tmp['駅名'] == '大久保') & (tmp['路線名'] == '中央線'), '駅名'] = '大久保' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '大倉山') & (tmp['路線名'] == '山手線'), '駅名'] = '大倉山' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '大倉山') & (tmp['路線名'] == '東横線'), '駅名'] = '大倉山' + '_' + '神奈川'

tmp.loc[(tmp['駅名'] == '大和田') & (tmp['路線名'] == '京阪本線'), '駅名'] = '大和田' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '大和田') & (tmp['路線名'] == '大井川本線'), '駅名'] = '大和田' + '_' + '静岡'
tmp.loc[(tmp['駅名'] == '大和田') & (tmp['路線名'] == '野田線'), '駅名'] = '大和田' + '_' + '埼玉'

tmp.loc[(tmp['駅名'] == '大塚') & (tmp['路線名'] == '広島新交通1号線'), '駅名'] = '大塚' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '大塚') & (tmp['路線名'] == '山手線'), '駅名'] = '大塚' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '大宮') & (tmp['路線名'] == '京都線'), '駅名'] = '大宮' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '大宮') & (tmp['路線名'] == '伊奈線'), '駅名'] = '大宮' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '大宮') & (tmp['路線名'] == '東北線'), '駅名'] = '大宮' + '_' + '埼玉'
tmp.loc[(tmp['駅名'] == '大宮') & (tmp['路線名'] == '野田線'), '駅名'] = '大宮' + '_' + '埼玉'

tmp.loc[(tmp['駅名'] == '大手町') & (tmp['路線名'] == '高浜線'), '駅名'] = '大手町' + '_' + '愛媛'
tmp.loc[(tmp['駅名'] == '大手町') & (tmp['路線名'] == '4号線丸ノ内線'), '駅名'] = '大手町' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '大手町') & (tmp['路線名'] == '6号線三田線'), '駅名'] = '大手町' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '大町') & (tmp['路線名'] == '広島新交通1号線'), '駅名'] = '大町' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '大町') & (tmp['路線名'] == '志度線'), '駅名'] = '大町' + '_' + '香川'
tmp.loc[(tmp['駅名'] == '大町') & (tmp['路線名'] == '可部線'), '駅名'] = '大町' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '大町') & (tmp['路線名'] == '本線'), '駅名'] = '大町' + '_' + '北海道'
tmp.loc[(tmp['駅名'] == '大町') & (tmp['路線名'] == '本線'), '駅名'] = '大町' + '_' + '富山'
tmp.loc[(tmp['駅名'] == '大町') & (tmp['路線名'] == '北総線'), '駅名'] = '大町' + '_' + '千葉'

tmp.loc[(tmp['駅名'] == '大門') & (tmp['路線名'] == '愛知環状鉄道線'), '駅名'] = '大門' + '_' + '愛知'
tmp.loc[(tmp['駅名'] == '大門') & (tmp['路線名'] == '山陽線'), '駅名'] = '大門' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '大門') & (tmp['路線名'] == '1号線浅草線'), '駅名'] = '大門' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '大阪梅田') & (tmp['路線名'] == '神戸線'), '駅名'] = '大阪梅田' + '_' + '阪急'
tmp.loc[(tmp['駅名'] == '大阪梅田') & (tmp['路線名'] == '本線'), '駅名'] = '大阪梅田' + '_' + '阪神'

tmp.loc[(tmp['駅名'] == '太田') & (tmp['路線名'] == '琴平線'), '駅名'] = '太田' + '_' + '高松'
tmp.loc[(tmp['駅名'] == '太田') & (tmp['路線名'] == '伊勢崎線'), '駅名'] = '太田' + '_' + '群馬'

tmp.loc[(tmp['駅名'] == '学園前') & (tmp['路線名'] == '千原線'), '駅名'] = '学園前' + '_' + '千葉'
tmp.loc[(tmp['駅名'] == '学園前') & (tmp['路線名'] == '奈良線'), '駅名'] = '学園前' + '_' + '奈良'
tmp.loc[(tmp['駅名'] == '学園前') & (tmp['路線名'] == '東豊線'), '駅名'] = '学園前' + '_' + '札幌'

tmp.loc[(tmp['駅名'] == '宇治') & (tmp['路線名'] == '宇治線'), '駅名'] = '宇治' + '_' + '京阪'
tmp.loc[(tmp['駅名'] == '宇治') & (tmp['路線名'] == '奈良線'), '駅名'] = '宇治' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '富士見町') & (tmp['路線名'] == '江の島線'), '駅名'] = '富士見町' + '_' + '神奈川'
tmp.loc[(tmp['駅名'] == '富士見町') & (tmp['路線名'] == '境線'), '駅名'] = '富士見町' + '_' + '鳥取'

tmp.loc[(tmp['駅名'] == '富田') & (tmp['路線名'] == '京都線'), '駅名'] = '富田' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '富田') & (tmp['路線名'] == '関西線'), '駅名'] = '富田' + '_' + '三重'

tmp.loc[(tmp['駅名'] == '小倉') & (tmp['路線名'] == '京都線'), '駅名'] = '小倉' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '小倉') & (tmp['路線名'] == '鹿児島線'), '駅名'] = '小倉' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '小倉') & (tmp['路線名'] == '山陽新幹線'), '駅名'] = '小倉' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '小倉') & (tmp['路線名'] == '小倉線'), '駅名'] = '小倉' + '_' + '福岡'

tmp.loc[(tmp['駅名'] == '小野') & (tmp['路線名'] == '東西線'), '駅名'] = '小野' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '小野') & (tmp['路線名'] == '粟生線'), '駅名'] = '小野' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '小野') & (tmp['路線名'] == '湖西線'), '駅名'] = '小野' + '_' + '滋賀'
tmp.loc[(tmp['駅名'] == '小野') & (tmp['路線名'] == '島原鉄道線'), '駅名'] = '小野' + '_' + '鹿児島'
tmp.loc[(tmp['駅名'] == '小野') & (tmp['路線名'] == '中央線'), '駅名'] = '小野' + '_' + '長野'

tmp.loc[(tmp['駅名'] == '尼崎') & (tmp['路線名'] == '本線'), '駅名'] = '尼崎' + '_' + '阪神'
tmp.loc[(tmp['駅名'] == '尼崎') & (tmp['路線名'] == '東海道線'), '駅名'] = '尼崎' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '山下') & (tmp['路線名'] == '世田谷線'), '駅名'] = '山下' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '山下') & (tmp['路線名'] == '常磐線'), '駅名'] = '山下' + '_' + '宮城'
tmp.loc[(tmp['駅名'] == '山下') & (tmp['路線名'] == '妙見線'), '駅名'] = '山下' + '_' + '兵庫'

tmp.loc[(tmp['駅名'] == '山口') & (tmp['路線名'] == '愛知環状鉄道線'), '駅名'] = '山口' + '_' + '愛知'
tmp.loc[(tmp['駅名'] == '山口') & (tmp['路線名'] == '山口線'), '駅名'] = '山口' + '_' + '山口'

tmp.loc[(tmp['駅名'] == '山崎') & (tmp['路線名'] == '東海道線'), '駅名'] = '山崎' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '山崎') & (tmp['路線名'] == '尾西線'), '駅名'] = '山崎' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '山本') & (tmp['路線名'] == '筑肥線'), '駅名'] = '山本' + '_' + '佐賀'
tmp.loc[(tmp['駅名'] == '山本') & (tmp['路線名'] == '宝塚線'), '駅名'] = '山本' + '_' + '兵庫'

tmp.loc[(tmp['駅名'] == '山田') & (tmp['路線名'] == '高尾線'), '駅名'] = '山田' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '山田') & (tmp['路線名'] == '千里線'), '駅名'] = '山田' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '山田') & (tmp['路線名'] == '大阪モノレール線'), '駅名'] = '山田' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '山田') & (tmp['路線名'] == '越美南線'), '駅名'] = '山田' + '_' + '岐阜'

tmp.loc[(tmp['駅名'] == '岡本') & (tmp['路線名'] == '琴平線'), '駅名'] = '岡本' + '_' + '高松'
tmp.loc[(tmp['駅名'] == '岡本') & (tmp['路線名'] == '神戸線'), '駅名'] = '岡本' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '岡本') & (tmp['路線名'] == '東北線'), '駅名'] = '岡本' + '_' + '栃木'

tmp.loc[(tmp['駅名'] == '嵐山') & (tmp['路線名'] == '嵐山本線'), '駅名'] = '嵐山' + '_' + '京福'
tmp.loc[(tmp['駅名'] == '嵐山') & (tmp['路線名'] == '嵐山線'), '駅名'] = '嵐山' + '_' + '阪急'

tmp.loc[(tmp['駅名'] == '川内') & (tmp['路線名'] == '鹿児島線'), '駅名'] = '川内' + '_' + '鹿児島'
tmp.loc[(tmp['駅名'] == '川内') & (tmp['路線名'] == '肥薩おれんじ鉄道線'), '駅名'] = '川内' + '_' + '鹿児島'
tmp.loc[(tmp['駅名'] == '川内') & (tmp['路線名'] == '東西線'), '駅名'] = '川内' + '_' + '宮城'

tmp.loc[(tmp['駅名'] == '市役所前') & (tmp['路線名'] == '城南線'), '駅名'] = '市役所前' + '_' + '愛媛'
tmp.loc[(tmp['駅名'] == '市役所前') & (tmp['路線名'] == '紀州鉄道線'), '駅名'] = '市役所前' + '_' + '和歌山'
tmp.loc[(tmp['駅名'] == '市役所前') & (tmp['路線名'] == '宇品線'), '駅名'] = '市役所前' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '市役所前') & (tmp['路線名'] == '第一期線'), '駅名'] = '市役所前' + '_' + '鹿児島'
tmp.loc[(tmp['駅名'] == '市役所前') & (tmp['路線名'] == '1号線'), '駅名'] = '市役所前' + '_' + '千葉'
tmp.loc[(tmp['駅名'] == '市役所前') & (tmp['路線名'] == '長野線'), '駅名'] = '市役所前' + '_' + '長野'
tmp.loc[(tmp['駅名'] == '市役所前') & (tmp['路線名'] == '本線'), '駅名'] = '市役所前' + '_' + '函館'
tmp.loc[(tmp['駅名'] == '市役所前') & (tmp['路線名'] == '東田本線'), '駅名'] = '市役所前' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '常盤') & (tmp['路線名'] == '北野線'), '駅名'] = '常盤' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '常盤') & (tmp['路線名'] == '水島本線'), '駅名'] = '常盤' + '_' + '岡山'
tmp.loc[(tmp['駅名'] == '常盤') & (tmp['路線名'] == '宇部線'), '駅名'] = '常盤' + '_' + '山口'

tmp.loc[(tmp['駅名'] == '平井') & (tmp['路線名'] == '横河原線'), '駅名'] = '平井' + '_' + '愛媛'
tmp.loc[(tmp['駅名'] == '平井') & (tmp['路線名'] == '総武線'), '駅名'] = '平井' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '平和台') & (tmp['路線名'] == '流山線'), '駅名'] = '平和台' + '_' + '千葉'
tmp.loc[(tmp['駅名'] == '平和台') & (tmp['路線名'] == '8号線有楽町線'), '駅名'] = '平和台' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '平野') & (tmp['路線名'] == '関西線'), '駅名'] = '平野' + '_' + 'ＪＲ'
tmp.loc[(tmp['駅名'] == '平野') & (tmp['路線名'] == '2号線(谷町線)'), '駅名'] = '平野' + '_' + '大阪メトロ'
tmp.loc[(tmp['駅名'] == '平野') & (tmp['路線名'] == '妙見線'), '駅名'] = '平野' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '平野') & (tmp['路線名'] == '飯坂線'), '駅名'] = '平野' + '_' + '福島'

tmp.loc[(tmp['駅名'] == '府中') & (tmp['路線名'] == '京王線'), '駅名'] = '府中' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '府中') & (tmp['路線名'] == '徳島線'), '駅名'] = '府中' + '_' + '徳島'
tmp.loc[(tmp['駅名'] == '府中') & (tmp['路線名'] == '福塩線'), '駅名'] = '府中' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '府中') & (tmp['路線名'] == '天橋立鋼索鉄道'), '駅名'] = '府中' + '_' + '京都'

tmp.loc[(tmp['駅名'] == '弘明寺') & (tmp['路線名'] == '1号線'), '駅名'] = '弘明寺' + '_' + '横浜市営'
tmp.loc[(tmp['駅名'] == '弘明寺') & (tmp['路線名'] == '本線'), '駅名'] = '弘明寺' + '_' + '京急'

tmp.loc[(tmp['駅名'] == '御影') & (tmp['路線名'] == '神戸線'), '駅名'] = '御影' + '_' + '阪急'
tmp.loc[(tmp['駅名'] == '御影') & (tmp['路線名'] == '本線'), '駅名'] = '御影' + '_' + '阪神'

tmp.loc[(tmp['駅名'] == '戸田') & (tmp['路線名'] == '名古屋線'), '駅名'] = '戸田' + '_' + '愛知'
tmp.loc[(tmp['駅名'] == '戸田') & (tmp['路線名'] == '山陽線'), '駅名'] = '戸田' + '_' + '山口'
tmp.loc[(tmp['駅名'] == '戸田') & (tmp['路線名'] == '東北線（埼京線）'), '駅名'] = '戸田' + '_' + '埼玉'

tmp.loc[(tmp['駅名'] == '新川町') & (tmp['路線名'] == '湯の川線'), '駅名'] = '新川町' + '_' + '函館'
tmp.loc[(tmp['駅名'] == '新川町') & (tmp['路線名'] == '三河線'), '駅名'] = '新川町' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '新栄町') & (tmp['路線名'] == '天神大牟田線'), '駅名'] = '新栄町' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '新栄町') & (tmp['路線名'] == '1号線東山線'), '駅名'] = '新栄町' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '新田') & (tmp['路線名'] == '阿武隈急行線'), '駅名'] = '新田' + '_' + '福島'
tmp.loc[(tmp['駅名'] == '新田') & (tmp['路線名'] == '奈良線'), '駅名'] = '新田' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '新田') & (tmp['路線名'] == '伊勢崎線'), '駅名'] = '新田' + '_' + '埼玉'

tmp.loc[(tmp['駅名'] == '新町') & (tmp['路線名'] == '上熊本線'), '駅名'] = '新町' + '_' + '熊本'
tmp.loc[(tmp['駅名'] == '新町') & (tmp['路線名'] == '高崎線'), '駅名'] = '新町' + '_' + '群馬'

tmp.loc[(tmp['駅名'] == '日本橋') & (tmp['路線名'] == '5号線(千日前線)'), '駅名'] = '日本橋' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '日本橋') & (tmp['路線名'] == '5号線東西線'), '駅名'] = '日本橋' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '日本橋') & (tmp['路線名'] == '1号線浅草線'), '駅名'] = '日本橋' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '日比野') & (tmp['路線名'] == '2号線名港線'), '駅名'] = '日比野' + '_' + '名古屋市営'
tmp.loc[(tmp['駅名'] == '日比野') & (tmp['路線名'] == '尾西線'), '駅名'] = '日比野' + '_' + '名鉄'

tmp.loc[(tmp['駅名'] == '日進') & (tmp['路線名'] == '川越線'), '駅名'] = '日進' + '_' + '埼玉'
tmp.loc[(tmp['駅名'] == '日進') & (tmp['路線名'] == '豊田線'), '駅名'] = '日進' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '早稲田') & (tmp['路線名'] == '5号線東西線'), '駅名'] = '早稲田' + '_' + 'メトロ'
tmp.loc[(tmp['駅名'] == '早稲田') & (tmp['路線名'] == '荒川線'), '駅名'] = '早稲田' + '_' + '都電'

tmp.loc[(tmp['駅名'] == '春日') & (tmp['路線名'] == '鹿児島線'), '駅名'] = '春日' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '春日') & (tmp['路線名'] == '6号線三田線'), '駅名'] = '春日' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '春日井') & (tmp['路線名'] == '中央線'), '駅名'] = '春日井' + '_' + 'ＪＲ'
tmp.loc[(tmp['駅名'] == '春日井') & (tmp['路線名'] == '小牧線'), '駅名'] = '春日井' + '_' + '名鉄'

tmp.loc[(tmp['駅名'] == '春日野道') & (tmp['路線名'] == '神戸線'), '駅名'] = '春日野道' + '_' + '阪急'
tmp.loc[(tmp['駅名'] == '春日野道') & (tmp['路線名'] == '本線'), '駅名'] = '春日野道' + '_' + '阪神'

tmp.loc[(tmp['駅名'] == '昭和町') & (tmp['路線名'] == '高徳線'), '駅名'] = '昭和町' + '_' + '香川'
tmp.loc[(tmp['駅名'] == '昭和町') & (tmp['路線名'] == '1号線(御堂筋線)'), '駅名'] = '昭和町' + '_' + '大阪'

tmp.loc[(tmp['駅名'] == '朝倉') & (tmp['路線名'] == '土讃線'), '駅名'] = '朝倉' + '_' + 'ＪＲ'
tmp.loc[(tmp['駅名'] == '朝倉') & (tmp['路線名'] == '伊野線'), '駅名'] = '朝倉' + '_' + '高知'
tmp.loc[(tmp['駅名'] == '朝倉') & (tmp['路線名'] == '常滑線'), '駅名'] = '朝倉' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '木幡') & (tmp['路線名'] == '宇治線'), '駅名'] = '木幡' + '_' + '京阪'
tmp.loc[(tmp['駅名'] == '木幡') & (tmp['路線名'] == '粟生線'), '駅名'] = '木幡' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '木幡') & (tmp['路線名'] == '奈良線'), '駅名'] = '木幡' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '木津') & (tmp['路線名'] == '粟生線'), '駅名'] = '木津' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '木津') & (tmp['路線名'] == '関西線'), '駅名'] = '木津' + '_' + '京都'

tmp.loc[(tmp['駅名'] == '末広町') & (tmp['路線名'] == '3号線銀座線'), '駅名'] = '末広町' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '末広町') & (tmp['路線名'] == '本線'), '駅名'] = '末広町' + '_' + '函館'
tmp.loc[(tmp['駅名'] == '末広町') & (tmp['路線名'] == '高岡軌道線'), '駅名'] = '末広町' + '_' + '富山'

tmp.loc[(tmp['駅名'] == '本郷') & (tmp['路線名'] == '甘木線'), '駅名'] = '本郷' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '本郷') & (tmp['路線名'] == '山陽線'), '駅名'] = '本郷' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '本郷') & (tmp['路線名'] == '長野線'), '駅名'] = '本郷' + '_' + '長野'
tmp.loc[(tmp['駅名'] == '本郷') & (tmp['路線名'] == '1号線東山線'), '駅名'] = '本郷' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '東山') & (tmp['路線名'] == '東西線'), '駅名'] = '東山' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '東山') & (tmp['路線名'] == '生駒線'), '駅名'] = '東山' + '_' + '奈良'

tmp.loc[(tmp['駅名'] == '東山公園') & (tmp['路線名'] == '山陰線'), '駅名'] = '東山公園' + '_' + '鳥取'
tmp.loc[(tmp['駅名'] == '東山公園') & (tmp['路線名'] == '1号線東山線'), '駅名'] = '東山公園' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '柚木') & (tmp['路線名'] == '静岡清水線'), '駅名'] = '柚木' + '_' + '静岡鉄道'
tmp.loc[(tmp['駅名'] == '柚木') & (tmp['路線名'] == '身延線'), '駅名'] = '柚木' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '栄') & (tmp['路線名'] == '粟生線'), '駅名'] = '栄' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '栄') & (tmp['路線名'] == '水島本線'), '駅名'] = '栄' + '_' + '岡山'
tmp.loc[(tmp['駅名'] == '栄') & (tmp['路線名'] == '1号線東山線'), '駅名'] = '栄' + '_' + '名古屋'

tmp.loc[(tmp['駅名'] == '栄町') & (tmp['路線名'] == '東豊線'), '駅名'] = '栄町' + '_' + '札幌'
tmp.loc[(tmp['駅名'] == '栄町') & (tmp['路線名'] == '1号線'), '駅名'] = '栄町' + '_' + '千葉'
tmp.loc[(tmp['駅名'] == '栄町') & (tmp['路線名'] == '荒川線'), '駅名'] = '栄町' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '栄町') & (tmp['路線名'] == '瀬戸線'), '駅名'] = '栄町' + '_' + '名古屋'
tmp.loc[(tmp['駅名'] == '栄町') & (tmp['路線名'] == '不二越線'), '駅名'] = '栄町' + '_' + '富山'

tmp.loc[(tmp['駅名'] == '桜井') & (tmp['路線名'] == '大阪線'), '駅名'] = '桜井' + '_' + '奈良'
tmp.loc[(tmp['駅名'] == '桜井') & (tmp['路線名'] == '箕面線'), '駅名'] = '桜井' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '桜井') & (tmp['路線名'] == '桜井線'), '駅名'] = '桜井' + '_' + '奈良'
tmp.loc[(tmp['駅名'] == '桜井') & (tmp['路線名'] == '西尾線'), '駅名'] = '桜井' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '桜台') & (tmp['路線名'] == '天神大牟田線'), '駅名'] = '桜台' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '桜台') & (tmp['路線名'] == '池袋線'), '駅名'] = '桜台' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '梅林') & (tmp['路線名'] == '可部線'), '駅名'] = '梅林' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '梅林') & (tmp['路線名'] == '3号線(七隈線)'), '駅名'] = '梅林' + '_' + '福岡'

tmp.loc[(tmp['駅名'] == '森下') & (tmp['路線名'] == '筑豊電気鉄道線'), '駅名'] = '森下' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '森下') & (tmp['路線名'] == '10号線新宿線'), '駅名'] = '森下' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '森下') & (tmp['路線名'] == '瀬戸線'), '駅名'] = '森下' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '橋本') & (tmp['路線名'] == '相模原線'), '駅名'] = '橋本' + '_' + '神奈川'
tmp.loc[(tmp['駅名'] == '橋本') & (tmp['路線名'] == '京阪本線'), '駅名'] = '橋本' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '橋本') & (tmp['路線名'] == '和歌山線'), '駅名'] = '橋本' + '_' + '和歌山'
tmp.loc[(tmp['駅名'] == '橋本') & (tmp['路線名'] == '横浜線'), '駅名'] = '橋本' + '_' + '神奈川'
tmp.loc[(tmp['駅名'] == '橋本') & (tmp['路線名'] == '高野線'), '駅名'] = '橋本' + '_' + '和歌山'
tmp.loc[(tmp['駅名'] == '橋本') & (tmp['路線名'] == '3号線(七隈線)'), '駅名'] = '橋本' + '_' + '福岡'

tmp.loc[(tmp['駅名'] == '比良') & (tmp['路線名'] == '湖西線'), '駅名'] = '比良' + '_' + '滋賀'
tmp.loc[(tmp['駅名'] == '比良') & (tmp['路線名'] == '城北線'), '駅名'] = '比良' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '池田') & (tmp['路線名'] == '菊池線'), '駅名'] = '池田' + '_' + '熊本'
tmp.loc[(tmp['駅名'] == '池田') & (tmp['路線名'] == '宝塚線'), '駅名'] = '池田' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '池田') & (tmp['路線名'] == '根室線'), '駅名'] = '池田' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == '河原町') & (tmp['路線名'] == '幹線'), '駅名'] = '河原町' + '_' + '熊本'
tmp.loc[(tmp['駅名'] == '河原町') & (tmp['路線名'] == '南北線'), '駅名'] = '河原町' + '_' + '宮城'

tmp.loc[(tmp['駅名'] == '泉') & (tmp['路線名'] == '常磐線'), '駅名'] = '泉' + '_' + 'ＪＲ'
tmp.loc[(tmp['駅名'] == '泉') & (tmp['路線名'] == '飯坂線'), '駅名'] = '泉' + '_' + '福島交通'

tmp.loc[(tmp['駅名'] == '浅草') & (tmp['路線名'] == '常磐新線'), '駅名'] = '浅草' + '_' + 'つくばＥＸＰ'
tmp.loc[(tmp['駅名'] == '浅草') & (tmp['路線名'] == '3号線銀座線'), '駅名'] = '浅草' + '_' + '東武・都営・メトロ'
tmp.loc[(tmp['駅名'] == '浅草') & (tmp['路線名'] == '1号線浅草線'), '駅名'] = '浅草' + '_' + '東武・都営・メトロ'
tmp.loc[(tmp['駅名'] == '浅草') & (tmp['路線名'] == '伊勢崎線'), '駅名'] = '浅草' + '_' + '東武・都営・メトロ'

tmp.loc[(tmp['駅名'] == '清水') & (tmp['路線名'] == '東海道線'), '駅名'] = '清水' + '_' + '静岡'
tmp.loc[(tmp['駅名'] == '清水') & (tmp['路線名'] == '瀬戸線'), '駅名'] = '清水' + '_' + '愛知'
tmp.loc[(tmp['駅名'] == '清水') & (tmp['路線名'] == '8号線（今里筋線）'), '駅名'] = '清水' + '_' + '大阪メトロ'

tmp.loc[(tmp['駅名'] == '牛田') & (tmp['路線名'] == '広島新交通1号線'), '駅名'] = '牛田' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '牛田') & (tmp['路線名'] == '伊勢崎線'), '駅名'] = '牛田' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '牛田') & (tmp['路線名'] == '名古屋本線'), '駅名'] = '牛田' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '玉造') & (tmp['路線名'] == '大阪環状線'), '駅名'] = '玉造' + '_' + 'ＪＲ'
tmp.loc[(tmp['駅名'] == '玉造') & (tmp['路線名'] == '7号線(長堀鶴見緑地線)'), '駅名'] = '玉造' + '_' + '大阪メトロ'

tmp.loc[(tmp['駅名'] == '琴似') & (tmp['路線名'] == '東西線'), '駅名'] = '琴似' + '_' + '札幌市営'
tmp.loc[(tmp['駅名'] == '琴似') & (tmp['路線名'] == '函館線'), '駅名'] = '琴似' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '瓢箪山') & (tmp['路線名'] == '奈良線'), '駅名'] = '瓢箪山' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '瓢箪山') & (tmp['路線名'] == '瀬戸線'), '駅名'] = '瓢箪山' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '田原町') & (tmp['路線名'] == '三国芦原線'), '駅名'] = '田原町' + '_' + '福井'
tmp.loc[(tmp['駅名'] == '田原町') & (tmp['路線名'] == '3号線銀座線'), '駅名'] = '田原町' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '白山') & (tmp['路線名'] == '長尾線'), '駅名'] = '白山' + '_' + '高松'
tmp.loc[(tmp['駅名'] == '白山') & (tmp['路線名'] == '6号線三田線'), '駅名'] = '白山' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '白山') & (tmp['路線名'] == '越後線'), '駅名'] = '白山' + '_' + '新潟'

tmp.loc[(tmp['駅名'] == '白石') & (tmp['路線名'] == '東西線'), '駅名'] = '白石' + '_' + '札幌市営'
tmp.loc[(tmp['駅名'] == '白石') & (tmp['路線名'] == '東北線'), '駅名'] = '白石' + '_' + '白石'
tmp.loc[(tmp['駅名'] == '白石') & (tmp['路線名'] == '函館線'), '駅名'] = '白石' + '_' + 'ＪＲ北海道'

tmp.loc[(tmp['駅名'] == '県庁前') & (tmp['路線名'] == '城南線'), '駅名'] = '県庁前' + '_' + '愛媛'
tmp.loc[(tmp['駅名'] == '県庁前') & (tmp['路線名'] == '沖縄都市モノレール線'), '駅名'] = '県庁前' + '_' + '沖縄'
tmp.loc[(tmp['駅名'] == '県庁前') & (tmp['路線名'] == '広島新交通1号線'), '駅名'] = '県庁前' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '県庁前') & (tmp['路線名'] == '山手線'), '駅名'] = '県庁前' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '県庁前') & (tmp['路線名'] == '1号線'), '駅名'] = '県庁前' + '_' + '千葉'
tmp.loc[(tmp['駅名'] == '県庁前') & (tmp['路線名'] == '伊野線'), '駅名'] = '県庁前' + '_' + '高知'
tmp.loc[(tmp['駅名'] == '県庁前') & (tmp['路線名'] == '支線'), '駅名'] = '県庁前' + '_' + '富山'

tmp.loc[(tmp['駅名'] == '矢田') & (tmp['路線名'] == '南大阪線'), '駅名'] = '矢田' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '矢田') & (tmp['路線名'] == '瀬戸線'), '駅名'] = '矢田' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '石田') & (tmp['路線名'] == '東西線'), '駅名'] = '石田' + '_' + '京都市営'
tmp.loc[(tmp['駅名'] == '石田') & (tmp['路線名'] == '日田彦山線'), '駅名'] = '石田' + '_' + '福岡'

tmp.loc[(tmp['駅名'] == '福井') & (tmp['路線名'] == '勝山永平寺線'), '駅名'] = '福井' + '_' + '福井'
tmp.loc[(tmp['駅名'] == '福井') & (tmp['路線名'] == '水島本線'), '駅名'] = '福井' + '_' + '岡山'
tmp.loc[(tmp['駅名'] == '福井') & (tmp['路線名'] == '北陸線'), '駅名'] = '福井' + '_' + '福井'

tmp.loc[(tmp['駅名'] == '福島') & (tmp['路線名'] == '阿武隈急行線'), '駅名'] = '福島' + '_' + '福島'
tmp.loc[(tmp['駅名'] == '福島') & (tmp['路線名'] == '本線'), '駅名'] = '福島' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '福島') & (tmp['路線名'] == '大阪環状線'), '駅名'] = '福島' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '福島') & (tmp['路線名'] == '東北線'), '駅名'] = '福島' + '_' + '福島'
tmp.loc[(tmp['駅名'] == '福島') & (tmp['路線名'] == '飯坂線'), '駅名'] = '福島' + '_' + '福島'

tmp.loc[(tmp['駅名'] == '稲荷町') & (tmp['運営会社'] == '広島電鉄'), '駅名'] = '稲荷町' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '稲荷町') & (tmp['路線名'] == '3号線銀座線'), '駅名'] = '稲荷町' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '稲荷町') & (tmp['運営会社'] == '富山地方鉄道'), '駅名'] = '稲荷町' + '_' + '富山'

tmp.loc[(tmp['駅名'] == '競馬場前') & (tmp['路線名'] == '湯の川線'), '駅名'] = '競馬場前' + '_' + '函館'
tmp.loc[(tmp['駅名'] == '競馬場前') & (tmp['路線名'] == '小倉線'), '駅名'] = '競馬場前' + '_' + '福岡'

tmp.loc[(tmp['駅名'] == '筒井') & (tmp['路線名'] == '橿原線'), '駅名'] = '筒井' + '_' + '奈良'
tmp.loc[(tmp['駅名'] == '筒井') & (tmp['路線名'] == '青い森鉄道線'), '駅名'] = '筒井' + '_' + '青森'

tmp.loc[(tmp['駅名'] == '緑が丘') & (tmp['路線名'] == '粟生線'), '駅名'] = '緑が丘' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '緑が丘') & (tmp['路線名'] == '大井町線'), '駅名'] = '緑が丘' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '芦屋') & (tmp['路線名'] == '本線'), '駅名'] = '芦屋' + '_' + '阪神'
tmp.loc[(tmp['駅名'] == '芦屋') & (tmp['路線名'] == '東海道線'), '駅名'] = '芦屋' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '花園') & (tmp['路線名'] == '長尾線'), '駅名'] = '花園' + '_' + '高松'
tmp.loc[(tmp['駅名'] == '花園') & (tmp['路線名'] == '山陰線'), '駅名'] = '花園' + '_' + '京都'

tmp.loc[(tmp['駅名'] == '若林') & (tmp['路線名'] == '世田谷線'), '駅名'] = '若林' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '若林') & (tmp['路線名'] == '三河線'), '駅名'] = '若林' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '茶山') & (tmp['路線名'] == '叡山本線'), '駅名'] = '茶山' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '茶山') & (tmp['路線名'] == '3号線(七隈線)'), '駅名'] = '茶山' + '_' + '福岡'

tmp.loc[(tmp['駅名'] == '草津') & (tmp['路線名'] == '宮島線'), '駅名'] = '草津' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '草津') & (tmp['路線名'] == '東海道線'), '駅名'] = '草津' + '_' + '滋賀'

tmp.loc[(tmp['駅名'] == '萩原') & (tmp['路線名'] == '筑豊電気鉄道線'), '駅名'] = '萩原' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '萩原') & (tmp['路線名'] == '尾西線'), '駅名'] = '萩原' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '藤が丘') & (tmp['路線名'] == '東部丘陵線'), '駅名'] = '藤が丘' + '_' + '愛知'
tmp.loc[(tmp['駅名'] == '藤が丘') & (tmp['路線名'] == '田園都市線'), '駅名'] = '藤が丘' + '_' + '神奈川'
tmp.loc[(tmp['駅名'] == '藤が丘') & (tmp['路線名'] == '1号線東山線'), '駅名'] = '藤が丘' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '西宮') & (tmp['路線名'] == '本線'), '駅名'] = '西宮' + '_' + '阪神'
tmp.loc[(tmp['駅名'] == '西宮') & (tmp['路線名'] == '東海道線'), '駅名'] = '西宮' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '西院') & (tmp['路線名'] == '嵐山本線'), '駅名'] = '西院' + '_' + '阪急'
tmp.loc[(tmp['駅名'] == '西院') & (tmp['路線名'] == '京都線'), '駅名'] = '西院' + '_' + '京福'

tmp.loc[(tmp['駅名'] == '谷山') & (tmp['路線名'] == '指宿枕崎線'), '駅名'] = '谷山' + '_' + 'ＪＲ'
tmp.loc[(tmp['駅名'] == '谷山') & (tmp['路線名'] == '谷山線'), '駅名'] = '谷山' + '_' + '市電'

tmp.loc[(tmp['駅名'] == '豊川') & (tmp['路線名'] == '飯田線'), '駅名'] = '豊川' + '_' + '愛知'
tmp.loc[(tmp['駅名'] == '豊川') & (tmp['路線名'] == '国際文化公園都市モノレール線（彩都線）'), '駅名'] = '豊川' + '_' + '大阪'

tmp.loc[(tmp['駅名'] == '貝塚') & (tmp['路線名'] == '水間線'), '駅名'] = '貝塚' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '貝塚') & (tmp['路線名'] == '貝塚線'), '駅名'] = '貝塚' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '貝塚') & (tmp['路線名'] == '南海本線'), '駅名'] = '貝塚' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '貝塚') & (tmp['路線名'] == '2号線(箱崎線)'), '駅名'] = '貝塚' + '_' + '福岡'

tmp.loc[(tmp['駅名'] == '赤坂') & (tmp['路線名'] == '上毛線'), '駅名'] = '赤坂' + '_' + '群馬'
tmp.loc[(tmp['駅名'] == '赤坂') & (tmp['路線名'] == '9号線千代田線'), '駅名'] = '赤坂' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '赤坂') & (tmp['路線名'] == '大月線'), '駅名'] = '赤坂' + '_' + '山梨'
tmp.loc[(tmp['駅名'] == '赤坂') & (tmp['路線名'] == '1号線(空港線)'), '駅名'] = '赤坂' + '_' + '福岡'

tmp.loc[(tmp['駅名'] == '追分') & (tmp['路線名'] == '京津線'), '駅名'] = '追分' + '_' + '滋賀'
tmp.loc[(tmp['駅名'] == '追分') & (tmp['路線名'] == '内部線'), '駅名'] = '追分' + '_' + '三重'
tmp.loc[(tmp['駅名'] == '追分') & (tmp['路線名'] == '奥羽線'), '駅名'] = '追分' + '_' + '秋田'
tmp.loc[(tmp['駅名'] == '追分') & (tmp['路線名'] == '室蘭線'), '駅名'] = '追分' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == '郡山') & (tmp['路線名'] == '関西線'), '駅名'] = '郡山' + '_' + '奈良'
tmp.loc[(tmp['駅名'] == '郡山') & (tmp['路線名'] == '東北線'), '駅名'] = '郡山' + '_' + '福島'

tmp.loc[(tmp['駅名'] == '野田') & (tmp['路線名'] == '本線'), '駅名'] = '野田' + '_' + '阪神'
tmp.loc[(tmp['駅名'] == '野田') & (tmp['路線名'] == '大阪環状線'), '駅名'] = '野田' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '金山') & (tmp['路線名'] == '中央線'), '駅名'] = '金山' + '_' + '愛知'
tmp.loc[(tmp['駅名'] == '金山') & (tmp['路線名'] == '3号線(七隈線)'), '駅名'] = '金山' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '金山') & (tmp['路線名'] == '2号線名城線'), '駅名'] = '金山' + '_' + '愛知'
tmp.loc[(tmp['駅名'] == '金山') & (tmp['路線名'] == '名古屋本線'), '駅名'] = '金山' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '長原') & (tmp['路線名'] == '2号線(谷町線)'), '駅名'] = '長原' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '長原') & (tmp['路線名'] == '池上線'), '駅名'] = '長原' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '長沼') & (tmp['路線名'] == '京王線'), '駅名'] = '長沼' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '長沼') & (tmp['路線名'] == '静岡清水線'), '駅名'] = '長沼' + '_' + '静岡'

tmp.loc[(tmp['駅名'] == '長浦') & (tmp['路線名'] == '内房線'), '駅名'] = '長浦' + '_' + '千葉'
tmp.loc[(tmp['駅名'] == '長浦') & (tmp['路線名'] == '常滑線'), '駅名'] = '長浦' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '長田') & (tmp['路線名'] == '山手線'), '駅名'] = '長田' + '_' + '神戸市営'
tmp.loc[(tmp['駅名'] == '長田') & (tmp['路線名'] == '有馬線'), '駅名'] = '長田' + '_' + '神戸電鉄'
tmp.loc[(tmp['駅名'] == '長田') & (tmp['路線名'] == '4号線(中央線)'), '駅名'] = '長田' + '_' + '大阪'

tmp.loc[(tmp['駅名'] == '青山') & (tmp['路線名'] == 'いわて銀河鉄道線'), '駅名'] = '青山' + '_' + '岩手'
tmp.loc[(tmp['駅名'] == '青山') & (tmp['路線名'] == '越後線'), '駅名'] = '青山' + '_' + '新潟'
tmp.loc[(tmp['駅名'] == '青山') & (tmp['路線名'] == '河和線'), '駅名'] = '青山' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '高井田') & (tmp['路線名'] == '関西線'), '駅名'] = '高井田' + '_' + 'ＪＲ'
tmp.loc[(tmp['駅名'] == '高井田') & (tmp['路線名'] == '4号線(中央線)'), '駅名'] = '高井田' + '_' + '大阪メトロ'

tmp.loc[(tmp['駅名'] == '高崎') & (tmp['路線名'] == '上信線'), '駅名'] = '高崎' + '_' + '上信'
tmp.loc[(tmp['駅名'] == '高崎') & (tmp['路線名'] == '上越線'), '駅名'] = '高崎' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '高松') & (tmp['路線名'] == '予讃線'), '駅名'] = '高松' + '_' + '香川'
tmp.loc[(tmp['駅名'] == '高松') & (tmp['路線名'] == '七尾線'), '駅名'] = '高松' + '_' + '石川'
tmp.loc[(tmp['駅名'] == '高松') & (tmp['路線名'] == '多摩都市モノレール線'), '駅名'] = '高松' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '高田') & (tmp['路線名'] == '甘木線'), '駅名'] = '高田' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '高田') & (tmp['路線名'] == '長崎線'), '駅名'] = '高田' + '_' + '長崎'
tmp.loc[(tmp['駅名'] == '高田') & (tmp['路線名'] == '長尾線'), '駅名'] = '高田' + '_' + '香川'
tmp.loc[(tmp['駅名'] == '高田') & (tmp['路線名'] == '和歌山線'), '駅名'] = '高田' + '_' + '奈良'
tmp.loc[(tmp['駅名'] == '高田') & (tmp['路線名'] == '妙高はねうまライン'), '駅名'] = '高田' + '_' + '新潟'
tmp.loc[(tmp['駅名'] == '高田') & (tmp['路線名'] == '4号線'), '駅名'] = '高田' + '_' + '神奈川'

tmp.loc[(tmp['駅名'] == '黄檗') & (tmp['路線名'] == '宇治線'), '駅名'] = '黄檗' + '_' + '京阪'
tmp.loc[(tmp['駅名'] == '黄檗') & (tmp['路線名'] == '奈良線'), '駅名'] = '黄檗' + '_' + 'ＪＲ'

tmp.loc[(tmp['駅名'] == '黒川') & (tmp['路線名'] == '土讃線'), '駅名'] = '黒川' + '_' + '香川'
tmp.loc[(tmp['駅名'] == '黒川') & (tmp['路線名'] == '多摩線'), '駅名'] = '黒川' + '_' + '神奈川'
tmp.loc[(tmp['駅名'] == '黒川') & (tmp['路線名'] == '西九州線'), '駅名'] = '黒川' + '_' + '佐賀'
tmp.loc[(tmp['駅名'] == '黒川') & (tmp['路線名'] == '鋼索線'), '駅名'] = '黒川' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '黒川') & (tmp['路線名'] == '2号線名城線'), '駅名'] = '黒川' + '_' + '愛知'

# %%
# 乗降客数0の駅
tmp.loc[(tmp['駅名'] == '中田') & (tmp['路線名'] == '五能線'), '駅名'] = '中田' + '_' + '青森'

tmp.loc[(tmp['駅名'] == '今津') & (tmp['路線名'] == '日豊線'), '駅名'] = '今津' + '_' + '大分'

tmp.loc[(tmp['駅名'] == '住吉') & (tmp['路線名'] == '三角線'), '駅名'] = '住吉' + '_' + '熊本'

tmp.loc[(tmp['駅名'] == '大和田') & (tmp['路線名'] == '留萌線'), '駅名'] = '大和田' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == '大町') & (tmp['路線名'] == '佐世保線'), '駅名'] = '大町' + '_' + '佐賀'

tmp.loc[(tmp['駅名'] == '富田') & (tmp['路線名'] == '両毛線'), '駅名'] = '富田' + '_' + '栃木'

tmp.loc[(tmp['駅名'] == '山崎') & (tmp['路線名'] == '函館線'), '駅名'] = '山崎' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == '川内') & (tmp['路線名'] == '山田線'), '駅名'] = '川内' + '_' + '岩手'

tmp.loc[(tmp['駅名'] == '御影') & (tmp['路線名'] == '根室線'), '駅名'] = '御影' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == '新田') & (tmp['路線名'] == '東北線'), '駅名'] = '新田' + '_' + '宮城'

tmp.loc[(tmp['駅名'] == '日進') & (tmp['路線名'] == '宗谷線'), '駅名'] = '日進' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == '東山') & (tmp['路線名'] == '函館線'), '駅名'] = '東山' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == '田原町') & (tmp['路線名'] == '福武線'), '駅名'] = '田原町' + '_' + '福井'

tmp.loc[(tmp['駅名'] == '白石') & (tmp['路線名'] == '肥薩線'), '駅名'] = '白石' + '_' + '熊本'

tmp.loc[(tmp['駅名'] == '緑が丘') & (tmp['路線名'] == '富良野線'), '駅名'] = '緑が丘' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == '金山') & (tmp['路線名'] == '根室線'), '駅名'] = '金山' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == '長田') & (tmp['路線名'] == 'けいはんな線'), '駅名'] = '長田' + '_' + '大阪'

# %%
for station in samelist:
    if len(tmp[tmp['駅名'] == station]) > 0:
        display(tmp[tmp['駅名'] == station])
        for line in  tmp[tmp['駅名'] == station]['路線名']:
            print("tmp.loc[(tmp['駅名'] == '" + station + "') & (tmp['路線名'] == '" + line + "'), '駅名'] = '" + station + "' + '_' + ''")
        print()

# %%
# ここまでで、同名駅はなくなったと思われる・・・

# %%
# 1つしかない駅名を編集する。
stationlist = ['平岸_札幌市営', '札幌_JR', 'ひばりが丘_北海道', 'さっぽろ_札幌市営', '高砂_北海道', '新川_北海道', 'すすきの_市営', '森林公園_北海道', '小柳_青森', '国見_宮城', '薬師堂_宮城', '旭ケ丘_宮城', '卸町_宮城', '黒松_宮城', '荒井_宮城', '愛宕_宮城', '細谷_群馬', '坂戸_埼玉', 'ひばりケ丘_東京', '霞ケ関_埼玉', '石原_埼玉', '浦安_千葉', '村上_千葉', '穴川_千葉', '愛宕_千葉', '桜木_千葉', '田町_東京', '梅屋敷_東京', '大島_東京', '大山_東京', '入谷_東京', '新富町_東京', '落合_東京', '大森_東京', '松原_東京', '雑司が谷_東京メトロ', '神田_東京', '東雲_東京', '有明_東京', '菊川_東京', '北野_東京', '中野_東京', '八丁堀_東京', '自由が丘_東京', '八坂_東京', '高尾_東京', '日野_東京', '小川町_東京', '小川_東京', '高野_東京', '宝町_東京', '向原_東京', '中川_神奈川', '生田_神奈川', '北山田_神奈川', '中山_神奈川', '日吉_神奈川', '十日市場_神奈川', '大和_神奈川', '高津_神奈川', '星川_神奈川', '番田_神奈川', '根岸_神奈川', 'こどもの国_神奈川', '杉田_神奈川', '香川_神奈川', '長谷_神奈川', '江田_神奈川', '足柄_神奈川', '入谷_神奈川', '宮内_新潟', '関屋_新潟', '月岡_新潟', '桐原_新潟', '稲荷町_富山', '大泉_富山', '蓮町_馬場記念公園前', '上本町_富山', '野々市_JR', '粟津_石川', '長野_JR・しなの', '平田_長野', '桐原_長野', '桜町_長野', '渚_長野', '柳津_岐阜', '六軒_岐阜', '関_岐阜', '島田_静岡', '草薙_JR', '大岡_静岡', 'ジヤトコ前_ジヤトコ1地区前', '御厨_静岡', '桜橋_静岡', '内海_愛知', '星ケ丘_愛知', '日比野_名古屋市営', '江南_愛知', '黄金_愛知', '丸の内_愛知', '岩倉_愛知', '自由ケ丘_愛知', '本山_愛知', '植田_名古屋市営', '喜多山_愛知', '観音寺_愛知', '古見_愛知', '山王_愛知', '赤池_愛知', '勝川_JR', '日比野_名鉄', '黒田_愛知', '桜_愛知', '名和_愛知', '大江_愛知', '羽黒_愛知', '榎戸_愛知', '小本_愛知', '山崎_愛知', '本宿_愛知', '運動公園前_愛知', '泊_三重', '松ケ崎_三重', '瀬田_滋賀', '四条_京都市営', '醍醐_京都', '五条_京都市営', '東野_京都', '丸太町_京都市営', '桂川_京都', '松ケ崎_京都', '太秦_JR', '竹田_京都', '加茂_京都', '寺田_京都', '山ノ内_京都', '山崎_京都', '扇町_大阪', '北浜_大阪', '玉川_大阪', '少路_大阪モノレール', '難波_大阪メトロ', '桜川_大阪', '平林_大阪', '吉田_大阪', '大正_大阪', '三国_大阪', '難波_南海', '中百舌鳥_大阪メトロ', '曽根_大阪', '南方_大阪', '豊津_大阪', '川西_大阪', '長尾_大阪', '今川_大阪', '下松_大阪', '万博記念公園_大阪', '中百舌鳥_南海・泉北', '滝谷_大阪', '庄内_大阪', '額田_大阪', '柏原_大阪', '星ケ丘_大阪', '小路_大阪メトロ', '上牧_大阪', '船尾_大阪', '野崎_大阪', '三ノ宮_JR', '妙法寺_兵庫', '神戸_兵庫', '深江_兵庫', '小林_兵庫', '山本_兵庫', '岩屋_兵庫', '霞ケ丘_兵庫', '多田_兵庫', '亀山_兵庫', '横山_兵庫', '広野_兵庫', '東松江_和歌山', '神前_和歌山', '高島_岡山', '球場前_岡山', '横川_広島', '西条_広島', '新白島_JR', '西原_広島', '大原_広島', '観音町_広島', '東新川_山口', '片原町_高松', '松山_愛媛', '旭_高知', '藤崎_福岡', '高宮_福岡', '大橋_福岡', '祇園_福岡', '西鉄福岡_天神', '北方_福岡', '西山_福岡', '志井_北九州モノレール', '浦田_福岡', '小郡_福岡', '荒尾_熊本', '山本_佐賀', '長崎_長崎', '上熊本_JR・熊本電鉄', '牧_大分', '加納_宮崎', '国分_鹿児島', '郡元_JR', '市立病院前_沖縄', '志井_JR', '千歳町_長崎']

# %%
for station in stationlist:
    if '_' in station:
        stationname = station.split('_')[0]
        if len(tmp[tmp['駅名'] == stationname]) <= 1:
            tmp.loc[(tmp['駅名'] == stationname), '駅名'] = station

# %%
stationlist = ['青葉', '朝里', '高砂_北海道', '新川_北海道', '稲穂', 'すすきの_市営', '森林公園_北海道',
       '百合が原', '太平', '旭川四条', '豊幌', '糸井', '近文', 'あいの里公園', '南永山', '小柳_青森',
       '小中野', '上盛岡', '大釜', '土沢', '山岸', '国見_宮城', '薬師堂_宮城', '葛岡', '旭ケ丘_宮城',
       '卸町_宮城', '黒松_宮城', '荒井_宮城', '中山平温泉', '万石浦', '東白石', '陸前谷地', '西塩釜',
       '塚目', '羽前千歳', '三瀬', '七日町', '笹木野', '偕楽園', '山前', '細谷_群馬', 'ひばりケ丘_東京',
       '霞ケ関_埼玉', '石原_埼玉', '西武園ゆうえんち', '多摩湖', '浦安_千葉', '村上_千葉', '穴川_千葉',
       '愛宕_千葉', '桜木_千葉', '東我孫子', '田町_東京', '梅屋敷_東京', '大島_東京', '新富町_東京',
       '大森_東京', '押上', '神田_東京', '東雲_東京', '東福生', '有明_東京', '菊川_東京', '北野_東京',
       '中野_東京', '八丁堀_東京', '八坂_東京', '高尾_東京', '日野_東京', '小川町_東京',
       'とうきょうスカイツリー', '小川_東京', '高野_東京', '宝町_東京', '二俣尾', '熊川', '宮ノ平',
       '向原_東京', '中山_神奈川', '日吉_神奈川', '十日市場_神奈川', '大和_神奈川', '高津_神奈川',
       '星川_神奈川', '鶴見小野', '門沢橋', 'こどもの国_神奈川', '小田栄', '浜川崎', '長谷_神奈川',
       '相武台下', '安善', '足柄_神奈川', '浅野', '国道', '社家', '弁天橋', '宮山', '武蔵白石',
       '入谷_神奈川', '宮内_新潟', '関屋_新潟', '北長岡', '西新発田', '岩室', '稲荷町_富山', '大泉_富山',
       'トヨタモビリティ富山 Gスクエア五福前', '蓮町_馬場記念公園前', '野々市_JR', '粟津_石川',
       '長野_JR・しなの', '平田_長野', '桐原_長野', '島内', '桜町_長野', '渚_長野', '柳津_岐阜',
       '六軒_岐阜', '関_岐阜', '島田_静岡', '草薙_JR', 'ジヤトコ前_ジヤトコ1地区前', '伊豆多賀',
       '御厨_静岡', '桜橋_静岡', '星ケ丘_愛知', '日比野_名古屋市営', '江南_愛知', '丸の内_愛知',
       '岩倉_愛知', '自由ケ丘_愛知', '本山_愛知', '植田_名古屋市営', '喜多山_愛知', '観音寺_愛知',
       '古見_愛知', '山王_愛知', '赤池_愛知', '勝川_JR', '日比野_名鉄', '黒田_愛知', '桜_愛知',
       '名和_愛知', '大江_愛知', '榎戸_愛知', '山崎_愛知', '本宿_愛知', '運動公園前_愛知', '泊_三重',
       '松ケ崎_三重', '五条_京都市営', '東野_京都', '桂川_京都', '松ケ崎_京都', '竹田_京都', '加茂_京都',
       '寺田_京都', '山ノ内_京都', '山崎_京都', '北浜_大阪', '難波_大阪メトロ', '桜川_大阪', '吉田_大阪',
       '大正_大阪', '三国_大阪', '難波_南海', '中百舌鳥_大阪メトロ', '曽根_大阪', '豊津_大阪', '川西_大阪',
       '長尾_大阪', '下松_大阪', '万博記念公園_大阪', '中百舌鳥_南海・泉北', '柏原_大阪', '星ケ丘_大阪',
       '野崎_大阪', '神戸_兵庫', '小林_兵庫', '山本_兵庫', '霞ケ丘_兵庫', '多田_兵庫', '亀山_兵庫',
       '横山_兵庫', '広野_兵庫', '東松江_和歌山', '神前_和歌山', '球場前_岡山', '横川_広島', '西条_広島',
       '新白島_JR', '西原_広島', '大原_広島', '観音町_広島', '東新川_山口', '片原町_高松', '松山_愛媛',
       '旭_高知', '高宮_福岡', '大橋_福岡', '御井', '西鉄福岡_天神', '善導寺', '藤ノ木', '大入',
       '荒尾_熊本', '西相知', '山本_佐賀', '長崎_長崎', '東諫早', '本諫早', '南風崎',
       '上熊本_JR・熊本電鉄', '牧_大分', '東別府', '海崎', '蓮ケ池', '田吉', '国分_鹿児島', '郡元_JR',
       '霧島神宮', '日当山', '嘉例川', '中福良', '市立病院前_沖縄', '伏石', '志井_JR', '千歳町_長崎']

# %%
stationlist = ['高砂', '新川', 'すすきの', '森林公園', '小柳', '国見', '薬師堂', '旭ケ丘', '卸町', '黒松', '荒井', '細谷', 'ひばりケ丘', '霞ケ関', '石原', '浦安', '村上', '穴川', '愛宕', '桜木', '田町', '梅屋敷', '大島', '新富町', '大森', '神田', '東雲', '有明', '菊川', '北野', '中野', '八丁堀', '八坂', '高尾', '日野', '小川町', '小川', '高野', '宝町', '向原', '中山', '日吉', '十日市場', '大和', '高津', '星川', 'こどもの国', '長谷', '足柄', '入谷', '宮内', '関屋', '稲荷町', '大泉', '蓮町', '野々市', '粟津', '長野', '平田', '桐原', '桜町', '渚', '柳津', '六軒', '関', '島田', '草薙', 'ジヤトコ前', '御厨', '桜橋', '星ケ丘', '日比野', '江南', '丸の内', '岩倉', '自由ケ丘', '本山', '植田', '喜多山', '観音寺', '古見', '山王', '赤池', '勝川', '日比野', '黒田', '桜', '名和', '大江', '榎戸', '山崎', '本宿', '運動公園前', '泊', '松ケ崎', '五条', '東野', '桂川', '松ケ崎', '竹田', '加茂', '寺田', '山ノ内', '山崎', '北浜', '難波', '桜川', '吉田', '大正', '三国', '難波', '中百舌鳥', '曽根', '豊津', '川西', '長尾', '下松', '万博記念公園', '中百舌鳥', '柏原', '星ケ丘', '野崎', '神戸', '小林', '山本', '霞ケ丘', '多田', '亀山', '横山', '広野', '東松江', '神前', '球場前', '横川', '西条', '新白島', '西原', '大原', '観音町', '東新川', '片原町', '松山', '旭', '高宮', '大橋', '西鉄福岡', '荒尾', '山本', '長崎', '上熊本', '牧', '国分', '郡元', '市立病院前', '志井', '千歳町']

# %%
tmp.loc[(tmp['駅名'] == '高砂') & (tmp['路線名'] == '本線'), '駅名'] = '高砂' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '高砂') & (tmp['路線名'] == '函館線'), '駅名'] = '高砂' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == '新川') & (tmp['路線名'] == '郡中線'), '駅名'] = '新川' + '_' + '愛媛'
tmp.loc[(tmp['駅名'] == '新川') & (tmp['路線名'] == '上毛線'), '駅名'] = '新川' + '_' + '群馬'
tmp.loc[(tmp['駅名'] == '新川') & (tmp['路線名'] == '東田本線'), '駅名'] = '新川' + '_' + '愛知'
tmp.loc[(tmp['駅名'] == '新川') & (tmp['路線名'] == '札沼線'), '駅名'] = '新川' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == 'すすきの') & (tmp['路線名'] == '山鼻線'), '駅名'] = 'すすきの' + '_' + '市営'
tmp.loc[(tmp['駅名'] == 'すすきの') & (tmp['路線名'] == '南北線'), '駅名'] = 'すすきの' + '_' + '市営'

tmp.loc[(tmp['駅名'] == '森林公園') & (tmp['路線名'] == '東上本線'), '駅名'] = '森林公園' + '_' + '埼玉'
tmp.loc[(tmp['駅名'] == '森林公園') & (tmp['路線名'] == '函館線'), '駅名'] = '森林公園' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == '小柳') & (tmp['路線名'] == '青い森鉄道線'), '駅名'] = '小柳' + '_' + '青森'
tmp.loc[(tmp['駅名'] == '小柳') & (tmp['路線名'] == '石川線'), '駅名'] = '小柳' + '_' + '石川'

tmp.loc[(tmp['駅名'] == '国見') & (tmp['路線名'] == '宿毛線'), '駅名'] = '国見' + '_' + '高知'
tmp.loc[(tmp['駅名'] == '国見') & (tmp['路線名'] == '仙山線'), '駅名'] = '国見' + '_' + '宮城'

tmp.loc[(tmp['駅名'] == '薬師堂') & (tmp['路線名'] == '鳥海山ろく線'), '駅名'] = '薬師堂' + '_' + '秋田'
tmp.loc[(tmp['駅名'] == '薬師堂') & (tmp['路線名'] == '東西線'), '駅名'] = '薬師堂' + '_' + '宮城'

tmp.loc[(tmp['駅名'] == '卸町') & (tmp['路線名'] == '阿武隈急行線'), '駅名'] = '卸町' + '_' + '福島'
tmp.loc[(tmp['駅名'] == '卸町') & (tmp['路線名'] == '東西線'), '駅名'] = '卸町' + '_' + '宮城'

tmp.loc[(tmp['駅名'] == '黒松') & (tmp['路線名'] == '山陰線'), '駅名'] = '黒松' + '_' + '島根'
tmp.loc[(tmp['駅名'] == '黒松') & (tmp['路線名'] == '南北線'), '駅名'] = '黒松' + '_' + '宮城'

tmp.loc[(tmp['駅名'] == '荒井') & (tmp['路線名'] == '本線'), '駅名'] = '荒井' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '荒井') & (tmp['路線名'] == '東西線'), '駅名'] = '荒井' + '_' + '宮城'

tmp.loc[(tmp['駅名'] == '細谷') & (tmp['路線名'] == '天竜浜名湖線'), '駅名'] = '細谷' + '_' + '静岡'
tmp.loc[(tmp['駅名'] == '細谷') & (tmp['路線名'] == '伊勢崎線'), '駅名'] = '細谷' + '_' + '群馬'

tmp.loc[(tmp['駅名'] == '石原') & (tmp['路線名'] == '山陰線'), '駅名'] = '石原' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '石原') & (tmp['路線名'] == '秩父本線'), '駅名'] = '石原' + '_' + '埼玉'

tmp.loc[(tmp['駅名'] == '浦安') & (tmp['路線名'] == '山陰線'), '駅名'] = '浦安' + '_' + '鳥取'
tmp.loc[(tmp['駅名'] == '浦安') & (tmp['路線名'] == '5号線東西線'), '駅名'] = '浦安' + '_' + '千葉'

tmp.loc[(tmp['駅名'] == '村上') & (tmp['路線名'] == '羽越線'), '駅名'] = '村上' + '_' + '新潟'
tmp.loc[(tmp['駅名'] == '村上') & (tmp['路線名'] == '東葉高速線'), '駅名'] = '村上' + '_' + '千葉'

tmp.loc[(tmp['駅名'] == '穴川') & (tmp['路線名'] == '志摩線'), '駅名'] = '穴川' + '_' + '三重'
tmp.loc[(tmp['駅名'] == '穴川') & (tmp['路線名'] == '2号線'), '駅名'] = '穴川' + '_' + '千葉'

tmp.loc[(tmp['駅名'] == '桜木') & (tmp['路線名'] == '2号線'), '駅名'] = '桜木' + '_' + '千葉'
tmp.loc[(tmp['駅名'] == '桜木') & (tmp['路線名'] == '天竜浜名湖線'), '駅名'] = '桜木' + '_' + '静岡'

tmp.loc[(tmp['駅名'] == '田町') & (tmp['路線名'] == '清輝橋線'), '駅名'] = '田町' + '_' + '岡山'
tmp.loc[(tmp['駅名'] == '田町') & (tmp['路線名'] == '東海道線'), '駅名'] = '田町' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '梅屋敷') & (tmp['路線名'] == '本線'), '駅名'] = '梅屋敷' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '梅屋敷') & (tmp['路線名'] == '生駒鋼索線'), '駅名'] = '梅屋敷' + '_' + '奈良'

tmp.loc[(tmp['駅名'] == '大島') & (tmp['路線名'] == '越美南線'), '駅名'] = '大島' + '_' + '岐阜'
tmp.loc[(tmp['駅名'] == '大島') & (tmp['路線名'] == '10号線新宿線'), '駅名'] = '大島' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '新富町') & (tmp['路線名'] == '8号線有楽町線'), '駅名'] = '新富町' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '新富町') & (tmp['路線名'] == '支線'), '駅名'] = '新富町' + '_' + '富山'

tmp.loc[(tmp['駅名'] == '大森') & (tmp['路線名'] == '東海道線'), '駅名'] = '大森' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '大森') & (tmp['路線名'] == '天竜浜名湖線'), '駅名'] = '大森' + '_' + '静岡'

tmp.loc[(tmp['駅名'] == '神田') & (tmp['路線名'] == '西九州線'), '駅名'] = '神田' + '_' + '長崎'
tmp.loc[(tmp['駅名'] == '神田') & (tmp['路線名'] == '3号線銀座線'), '駅名'] = '神田' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '神田') & (tmp['路線名'] == '中央線'), '駅名'] = '神田' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '東雲') & (tmp['路線名'] == 'りんかい線'), '駅名'] = '東雲' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '東雲') & (tmp['路線名'] == '宮津線'), '駅名'] = '東雲' + '_' + '京都'

tmp.loc[(tmp['駅名'] == '有明') & (tmp['路線名'] == '東京臨海新交通臨海線'), '駅名'] = '有明' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '有明') & (tmp['路線名'] == '大糸線'), '駅名'] = '有明' + '_' + '長野'

tmp.loc[(tmp['駅名'] == '菊川') & (tmp['路線名'] == '東海道線'), '駅名'] = '菊川' + '_' + '静岡'
tmp.loc[(tmp['駅名'] == '菊川') & (tmp['路線名'] == '10号線新宿線'), '駅名'] = '菊川' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '北野') & (tmp['路線名'] == '京王線'), '駅名'] = '北野' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '北野') & (tmp['路線名'] == '甘木線'), '駅名'] = '北野' + '_' + '福岡'

tmp.loc[(tmp['駅名'] == '中野') & (tmp['路線名'] == 'わたらせ渓谷線'), '駅名'] = '中野' + '_' + '群馬'
tmp.loc[(tmp['駅名'] == '中野') & (tmp['路線名'] == '別所線'), '駅名'] = '中野' + '_' + '長野'
tmp.loc[(tmp['駅名'] == '中野') & (tmp['路線名'] == '中央線'), '駅名'] = '中野' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '八丁堀') & (tmp['路線名'] == '白島線'), '駅名'] = '八丁堀' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '八丁堀') & (tmp['路線名'] == '本線'), '駅名'] = '八丁堀' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '八丁堀') & (tmp['路線名'] == '2号線日比谷線'), '駅名'] = '八丁堀' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '八丁堀') & (tmp['路線名'] == '京葉線'), '駅名'] = '八丁堀' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '八坂') & (tmp['路線名'] == '多摩湖線'), '駅名'] = '八坂' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '八坂') & (tmp['路線名'] == '越美南線'), '駅名'] = '八坂' + '_' + '岐阜'

tmp.loc[(tmp['駅名'] == '高尾') & (tmp['路線名'] == '高尾線'), '駅名'] = '高尾' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '高尾') & (tmp['路線名'] == '樽見線'), '駅名'] = '高尾' + '_' + '岐阜'
tmp.loc[(tmp['駅名'] == '高尾') & (tmp['路線名'] == '中央線'), '駅名'] = '高尾' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '日野') & (tmp['路線名'] == '本線'), '駅名'] = '日野' + '_' + '滋賀'
tmp.loc[(tmp['駅名'] == '日野') & (tmp['路線名'] == '長野線'), '駅名'] = '日野' + '_' + '長野'
tmp.loc[(tmp['駅名'] == '日野') & (tmp['路線名'] == '中央線'), '駅名'] = '日野' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '小川町') & (tmp['路線名'] == '10号線新宿線'), '駅名'] = '小川町' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '小川町') & (tmp['路線名'] == '東上本線'), '駅名'] = '小川町' + '_' + '埼玉'

tmp.loc[(tmp['駅名'] == '小川') & (tmp['路線名'] == '鹿児島線'), '駅名'] = '小川' + '_' + '鹿児島'
tmp.loc[(tmp['駅名'] == '小川') & (tmp['路線名'] == '拝島線'), '駅名'] = '小川' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '高野') & (tmp['路線名'] == '因美線'), '駅名'] = '高野' + '_' + '岡山'
tmp.loc[(tmp['駅名'] == '高野') & (tmp['路線名'] == '日暮里・舎人線'), '駅名'] = '高野' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '宝町') & (tmp['路線名'] == '本線'), '駅名'] = '宝町' + '_' + '長崎'
tmp.loc[(tmp['駅名'] == '宝町') & (tmp['路線名'] == '1号線浅草線'), '駅名'] = '宝町' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '向原') & (tmp['路線名'] == '芸備線'), '駅名'] = '向原' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '向原') & (tmp['路線名'] == '荒川線'), '駅名'] = '向原' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '中山') & (tmp['路線名'] == '伊野線'), '駅名'] = '中山' + '_' + '高知'
tmp.loc[(tmp['駅名'] == '中山') & (tmp['路線名'] == '横浜線'), '駅名'] = '中山' + '_' + '神奈川'
tmp.loc[(tmp['駅名'] == '中山') & (tmp['路線名'] == '4号線'), '駅名'] = '中山' + '_' + '神奈川'

tmp.loc[(tmp['駅名'] == '日吉') & (tmp['路線名'] == '山陰線'), '駅名'] = '日吉' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '日吉') & (tmp['路線名'] == '東横線'), '駅名'] = '日吉' + '_' + '神奈川'
tmp.loc[(tmp['駅名'] == '日吉') & (tmp['路線名'] == '4号線'), '駅名'] = '日吉' + '_' + '神奈川'

tmp.loc[(tmp['駅名'] == '十日市場') & (tmp['路線名'] == '横浜線'), '駅名'] = '十日市場' + '_' + '神奈川'
tmp.loc[(tmp['駅名'] == '十日市場') & (tmp['路線名'] == '大月線'), '駅名'] = '十日市場' + '_' + '山梨'

tmp.loc[(tmp['駅名'] == '大和') & (tmp['路線名'] == '江ノ島線'), '駅名'] = '大和' + '_' + '神奈川'
tmp.loc[(tmp['駅名'] == '大和') & (tmp['路線名'] == '本線'), '駅名'] = '大和' + '_' + '神奈川'

tmp.loc[(tmp['駅名'] == '高津') & (tmp['路線名'] == '山陰線'), '駅名'] = '高津' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '高津') & (tmp['路線名'] == '田園都市線'), '駅名'] = '高津' + '_' + '神奈川'

tmp.loc[(tmp['駅名'] == '星川') & (tmp['路線名'] == '北勢線'), '駅名'] = '星川' + '_' + '三重'
tmp.loc[(tmp['駅名'] == '星川') & (tmp['路線名'] == '本線'), '駅名'] = '星川' + '_' + '神奈川'

tmp.loc[(tmp['駅名'] == 'こどもの国') & (tmp['路線名'] == 'こどもの国線'), '駅名'] = 'こどもの国' + '_' + '神奈川'
tmp.loc[(tmp['駅名'] == 'こどもの国') & (tmp['路線名'] == '蒲郡線'), '駅名'] = 'こどもの国' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '長谷') & (tmp['路線名'] == '江ノ島電鉄線'), '駅名'] = '長谷' + '_' + '神奈川'
tmp.loc[(tmp['駅名'] == '長谷') & (tmp['路線名'] == '播但線'), '駅名'] = '長谷' + '_' + '兵庫'

tmp.loc[(tmp['駅名'] == '足柄') & (tmp['路線名'] == '小田原線'), '駅名'] = '足柄' + '_' + '神奈川'
tmp.loc[(tmp['駅名'] == '足柄') & (tmp['路線名'] == '御殿場線'), '駅名'] = '足柄' + '_' + '神奈川'

tmp.loc[(tmp['駅名'] == '宮内') & (tmp['路線名'] == '宮島線'), '駅名'] = '宮内' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '宮内') & (tmp['路線名'] == 'フラワー長井線'), '駅名'] = '宮内' + '_' + '山形'
tmp.loc[(tmp['駅名'] == '宮内') & (tmp['路線名'] == '上越線'), '駅名'] = '宮内' + '_' + '新潟'

tmp.loc[(tmp['駅名'] == '関屋') & (tmp['路線名'] == '大阪線'), '駅名'] = '関屋' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '関屋') & (tmp['路線名'] == '越後線'), '駅名'] = '関屋' + '_' + '新潟'

tmp.loc[(tmp['駅名'] == '大泉') & (tmp['路線名'] == '阿武隈急行線'), '駅名'] = '大泉' + '_' + '福島'
tmp.loc[(tmp['駅名'] == '大泉') & (tmp['路線名'] == '北勢線'), '駅名'] = '大泉' + '_' + '三重'
tmp.loc[(tmp['駅名'] == '大泉') & (tmp['路線名'] == '不二越線'), '駅名'] = '大泉' + '_' + '富山'

tmp.loc[(tmp['駅名'] == '野々市') & (tmp['路線名'] == '北陸線'), '駅名'] = '野々市' + '_' + 'JR'
tmp.loc[(tmp['駅名'] == '野々市') & (tmp['路線名'] == '石川線'), '駅名'] = '野々市' + '_' + '北陸鉄道'

tmp.loc[(tmp['駅名'] == '粟津') & (tmp['路線名'] == '石山坂本線'), '駅名'] = '粟津' + '_' + '滋賀'
tmp.loc[(tmp['駅名'] == '粟津') & (tmp['路線名'] == '北陸線'), '駅名'] = '粟津' + '_' + '石川'

tmp.loc[(tmp['駅名'] == '長野') & (tmp['路線名'] == '長野線'), '駅名'] = '長野' + '_' + 'JR・しなの'
tmp.loc[(tmp['駅名'] == '長野') & (tmp['路線名'] == '信越線'), '駅名'] = '長野' + '_' + 'JR・しなの'

tmp.loc[(tmp['駅名'] == '平田') & (tmp['路線名'] == '八日市線'), '駅名'] = '平田' + '_' + '滋賀'
tmp.loc[(tmp['駅名'] == '平田') & (tmp['路線名'] == 'リアス線'), '駅名'] = '平田' + '_' + '岩手'
tmp.loc[(tmp['駅名'] == '平田') & (tmp['路線名'] == '宿毛線'), '駅名'] = '平田' + '_' + '高知'
tmp.loc[(tmp['駅名'] == '平田') & (tmp['路線名'] == '篠ノ井線'), '駅名'] = '平田' + '_' + '長野'

tmp.loc[(tmp['駅名'] == '桜町') & (tmp['路線名'] == '桜町支線'), '駅名'] = '桜町' + '_' + '長崎'
tmp.loc[(tmp['駅名'] == '桜町') & (tmp['路線名'] == '飯田線'), '駅名'] = '桜町' + '_' + '長野'

tmp.loc[(tmp['駅名'] == '渚') & (tmp['路線名'] == '上高地線'), '駅名'] = '渚' + '_' + '長野'
tmp.loc[(tmp['駅名'] == '渚') & (tmp['路線名'] == '高山線'), '駅名'] = '渚' + '_' + '岐阜'

tmp.loc[(tmp['駅名'] == '柳津') & (tmp['路線名'] == '気仙沼線'), '駅名'] = '柳津' + '_' + '宮城'
tmp.loc[(tmp['駅名'] == '柳津') & (tmp['路線名'] == '竹鼻線'), '駅名'] = '柳津'# + '_' + '岐阜'

tmp.loc[(tmp['駅名'] == '六軒') & (tmp['路線名'] == '紀勢線'), '駅名'] = '六軒' + '_' + '宮城'
tmp.loc[(tmp['駅名'] == '六軒') & (tmp['路線名'] == '各務原線'), '駅名'] = '六軒' + '_' + '岐阜'

tmp.loc[(tmp['駅名'] == '関') & (tmp['路線名'] == '関西線'), '駅名'] = '関' + '_' + '三重'
tmp.loc[(tmp['駅名'] == '関') & (tmp['路線名'] == '越美南線'), '駅名'] = '関' + '_' + '岐阜'

tmp.loc[(tmp['駅名'] == '島田') & (tmp['路線名'] == '山陽線'), '駅名'] = '島田' + '_' + '山口'
tmp.loc[(tmp['駅名'] == '島田') & (tmp['路線名'] == '東海道線'), '駅名'] = '島田' + '_' + '静岡'

tmp.loc[(tmp['駅名'] == '草薙') & (tmp['路線名'] == '静岡清水線'), '駅名'] = '草薙' + '_' + '静岡鉄道'
tmp.loc[(tmp['駅名'] == '草薙') & (tmp['路線名'] == '東海道線'), '駅名'] = '草薙' + '_' + 'JR'

tmp.loc[(tmp['駅名'] == '御厨') & (tmp['路線名'] == '西九州線'), '駅名'] = '御厨' + '_' + '長崎'
tmp.loc[(tmp['駅名'] == '御厨') & (tmp['路線名'] == '東海道線'), '駅名'] = '御厨' + '_' + '静岡'

tmp.loc[(tmp['駅名'] == '桜橋') & (tmp['路線名'] == '静岡清水線'), '駅名'] = '桜橋' + '_' + '静岡'
tmp.loc[(tmp['駅名'] == '桜橋') & (tmp['路線名'] == '本線'), '駅名'] = '桜橋' + '_' + '富山'

tmp.loc[(tmp['駅名'] == '江南') & (tmp['路線名'] == '山陰線'), '駅名'] = '江南' + '_' + '島根'
tmp.loc[(tmp['駅名'] == '江南') & (tmp['路線名'] == '犬山線'), '駅名'] = '江南' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '丸の内') & (tmp['路線名'] == '安野屋線'), '駅名'] = '丸の内' + '_' + '富山'
tmp.loc[(tmp['駅名'] == '丸の内') & (tmp['路線名'] == '3号線鶴舞線'), '駅名'] = '丸の内' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '岩倉') & (tmp['路線名'] == '鞍馬線'), '駅名'] = '岩倉' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '岩倉') & (tmp['路線名'] == '宇部線'), '駅名'] = '岩倉' + '_' + '山口'
tmp.loc[(tmp['駅名'] == '岩倉') & (tmp['路線名'] == '犬山線'), '駅名'] = '岩倉' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '本山') & (tmp['路線名'] == '予讃線'), '駅名'] = '本山' + '_' + '香川'
tmp.loc[(tmp['駅名'] == '本山') & (tmp['路線名'] == '西九州線'), '駅名'] = '本山' + '_' + '長崎'
tmp.loc[(tmp['駅名'] == '本山') & (tmp['路線名'] == '1号線東山線'), '駅名'] = '本山' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '植田') & (tmp['路線名'] == '常磐線'), '駅名'] = '植田' + '_' + '福島'
tmp.loc[(tmp['駅名'] == '植田') & (tmp['路線名'] == '渥美線'), '駅名'] = '植田' + '_' + '豊橋鉄道'
tmp.loc[(tmp['駅名'] == '植田') & (tmp['路線名'] == '3号線鶴舞線'), '駅名'] = '植田' + '_' + '名古屋市営'

tmp.loc[(tmp['駅名'] == '喜多山') & (tmp['路線名'] == '内子線'), '駅名'] = '喜多山' + '_' + '愛媛'
tmp.loc[(tmp['駅名'] == '喜多山') & (tmp['路線名'] == '瀬戸線'), '駅名'] = '喜多山' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '観音寺') & (tmp['路線名'] == '予讃線'), '駅名'] = '観音寺' + '_' + '香川'
tmp.loc[(tmp['駅名'] == '観音寺') & (tmp['路線名'] == '尾西線'), '駅名'] = '観音寺' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '古見') & (tmp['路線名'] == '姫新線'), '駅名'] = '古見' + '_' + '岡山'
tmp.loc[(tmp['駅名'] == '古見') & (tmp['路線名'] == '常滑線'), '駅名'] = '古見' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '山王') & (tmp['路線名'] == '勝山永平寺線'), '駅名'] = '山王' + '_' + '福井'
tmp.loc[(tmp['駅名'] == '山王') & (tmp['路線名'] == '名古屋本線'), '駅名'] = '山王' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '赤池') & (tmp['路線名'] == '越美南線'), '駅名'] = '赤池' + '_' + '岐阜'
tmp.loc[(tmp['駅名'] == '赤池') & (tmp['路線名'] == '伊田線'), '駅名'] = '赤池' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '赤池') & (tmp['路線名'] == '3号線鶴舞線'), '駅名'] = '赤池' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '勝川') & (tmp['路線名'] == '城北線'), '駅名'] = '勝川' + '_' + '東海交通事業'
tmp.loc[(tmp['駅名'] == '勝川') & (tmp['路線名'] == '中央線'), '駅名'] = '勝川' + '_' + 'JR'

tmp.loc[(tmp['駅名'] == '黒田') & (tmp['路線名'] == '田原本線'), '駅名'] = '黒田' + '_' + '奈良'
tmp.loc[(tmp['駅名'] == '黒田') & (tmp['路線名'] == '名古屋本線'), '駅名'] = '黒田' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '桜') & (tmp['路線名'] == '湯の山線'), '駅名'] = '桜' + '_' + '三重'
tmp.loc[(tmp['駅名'] == '桜') & (tmp['路線名'] == '名古屋本線'), '駅名'] = '桜' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '名和') & (tmp['路線名'] == '山陰線'), '駅名'] = '名和' + '_' + '鳥取'
tmp.loc[(tmp['駅名'] == '名和') & (tmp['路線名'] == '常滑線'), '駅名'] = '名和' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '大江') & (tmp['路線名'] == '宮福線'), '駅名'] = '大江' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '大江') & (tmp['路線名'] == '常滑線'), '駅名'] = '大江' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '榎戸') & (tmp['路線名'] == '総武線'), '駅名'] = '榎戸' + '_' + '千葉'
tmp.loc[(tmp['駅名'] == '榎戸') & (tmp['路線名'] == '常滑線'), '駅名'] = '榎戸' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '本宿') & (tmp['路線名'] == 'わたらせ渓谷線'), '駅名'] = '本宿' + '_' + '群馬'
tmp.loc[(tmp['駅名'] == '本宿') & (tmp['路線名'] == '名古屋本線'), '駅名'] = '本宿' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '運動公園前') & (tmp['路線名'] == '弘南線'), '駅名'] = '運動公園前' + '_' + '青森'
tmp.loc[(tmp['駅名'] == '運動公園前') & (tmp['路線名'] == '東田本線'), '駅名'] = '運動公園前' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '泊') & (tmp['路線名'] == '内部線'), '駅名'] = '泊' + '_' + '三重'
tmp.loc[(tmp['駅名'] == '泊') & (tmp['路線名'] == '山陰線'), '駅名'] = '泊' + '_' + '鳥取'
tmp.loc[(tmp['駅名'] == '泊') & (tmp['路線名'] == 'あいの風とやま鉄道線'), '駅名'] = '泊' + '_' + '富山'

tmp.loc[(tmp['駅名'] == '五条') & (tmp['路線名'] == '烏丸線'), '駅名'] = '五条' #+ '_' + '京都'
tmp.loc[(tmp['駅名'] == '五条') & (tmp['路線名'] == '和歌山線'), '駅名'] = '五条' + '_' + '和歌山'

tmp.loc[(tmp['駅名'] == '東野') & (tmp['路線名'] == '東西線'), '駅名'] = '東野' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '東野') & (tmp['路線名'] == '明知線'), '駅名'] = '東野' + '_' + '岐阜'

tmp.loc[(tmp['駅名'] == '桂川') & (tmp['路線名'] == '筑豊線'), '駅名'] = '桂川' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '桂川') & (tmp['路線名'] == '東海道線'), '駅名'] = '桂川' + '_' + '京都'

tmp.loc[(tmp['駅名'] == '竹田') & (tmp['路線名'] == '烏丸線'), '駅名'] = '竹田' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '竹田') & (tmp['路線名'] == '播但線'), '駅名'] = '竹田' + '_' + '兵庫'

tmp.loc[(tmp['駅名'] == '加茂') & (tmp['路線名'] == '志摩線'), '駅名'] = '加茂' + '_' + '三重'
tmp.loc[(tmp['駅名'] == '加茂') & (tmp['路線名'] == '関西線'), '駅名'] = '加茂' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '加茂') & (tmp['路線名'] == '信越線'), '駅名'] = '加茂' + '_' + '新潟'

tmp.loc[(tmp['駅名'] == '寺田') & (tmp['路線名'] == '京都線'), '駅名'] = '寺田' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '寺田') & (tmp['路線名'] == '本線'), '駅名'] = '寺田' + '_' + '富山'

tmp.loc[(tmp['駅名'] == '山ノ内') & (tmp['路線名'] == '嵐山本線'), '駅名'] = '山ノ内' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '山ノ内') & (tmp['路線名'] == '芸備線'), '駅名'] = '山ノ内' + '_' + '広島'

tmp.loc[(tmp['駅名'] == '北浜') & (tmp['路線名'] == '京阪本線'), '駅名'] = '北浜' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '北浜') & (tmp['路線名'] == '6号線(堺筋線)'), '駅名'] = '北浜' + '_' + '大阪'

tmp.loc[(tmp['駅名'] == '難波') & (tmp['路線名'] == '1号線(御堂筋線)'), '駅名'] = '難波' + '_' + '大阪メトロ'
tmp.loc[(tmp['駅名'] == '難波') & (tmp['路線名'] == '南海本線'), '駅名'] = '難波' + '_' + '南海'

tmp.loc[(tmp['駅名'] == '桜川') & (tmp['路線名'] == '本線'), '駅名'] = '桜川' + '_' + '滋賀'
tmp.loc[(tmp['駅名'] == '桜川') & (tmp['路線名'] == '5号線(千日前線)'), '駅名'] = '桜川' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '桜川') & (tmp['路線名'] == '阪神なんば線'), '駅名'] = '桜川' + '_' + '大阪'

tmp.loc[(tmp['駅名'] == '吉田') & (tmp['路線名'] == 'けいはんな線'), '駅名'] = '吉田' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '吉田') & (tmp['路線名'] == '弥彦線'), '駅名'] = '吉田' + '_' + '新潟'

tmp.loc[(tmp['駅名'] == '大正') & (tmp['路線名'] == '大阪環状線'), '駅名'] = '大正' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '大正') & (tmp['路線名'] == '7号線(長堀鶴見緑地線)'), '駅名'] = '大正' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '大正') & (tmp['路線名'] == '島原鉄道線'), '駅名'] = '大正' + '_' + '長崎'

tmp.loc[(tmp['駅名'] == '三国') & (tmp['路線名'] == '三国芦原線'), '駅名'] = '三国' + '_' + '福井'
tmp.loc[(tmp['駅名'] == '三国') & (tmp['路線名'] == '宝塚線'), '駅名'] = '三国' + '_' + '大阪'

tmp.loc[(tmp['駅名'] == '中百舌鳥') & (tmp['路線名'] == '1号線(御堂筋線)'), '駅名'] = '中百舌鳥' + '_' + '大阪メトロ'
tmp.loc[(tmp['駅名'] == '中百舌鳥') & (tmp['路線名'] == '高野線'), '駅名'] = '中百舌鳥' + '_' + '南海・泉北'

tmp.loc[(tmp['駅名'] == '曽根') & (tmp['路線名'] == '宝塚線'), '駅名'] = '曽根' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '曽根') & (tmp['路線名'] == '山陽線'), '駅名'] = '曽根' + '_' + '兵庫'

tmp.loc[(tmp['駅名'] == '豊津') & (tmp['路線名'] == '千里線'), '駅名'] = '豊津' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '豊津') & (tmp['路線名'] == '田川線'), '駅名'] = '豊津' + '_' + '福岡'

tmp.loc[(tmp['駅名'] == '川西') & (tmp['路線名'] == '長野線'), '駅名'] = '川西' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '川西') & (tmp['路線名'] == '岩徳線'), '駅名'] = '川西' + '_' + '山口'

tmp.loc[(tmp['駅名'] == '長尾') & (tmp['路線名'] == '長尾線'), '駅名'] = '長尾' + '_' + '香川'
tmp.loc[(tmp['駅名'] == '長尾') & (tmp['路線名'] == '片町線'), '駅名'] = '長尾' + '_' + '大阪'

tmp.loc[(tmp['駅名'] == '下松') & (tmp['路線名'] == '阪和線'), '駅名'] = '下松' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '下松') & (tmp['路線名'] == '山陽線'), '駅名'] = '下松' + '_' + '山口'

tmp.loc[(tmp['駅名'] == '万博記念公園') & (tmp['路線名'] == '常磐新線'), '駅名'] = '万博記念公園' + '_' + '茨城'
tmp.loc[(tmp['駅名'] == '万博記念公園') & (tmp['路線名'] == '国際文化公園都市モノレール線（彩都線）'), '駅名'] = '万博記念公園' + '_' + '大阪'

tmp.loc[(tmp['駅名'] == '柏原') & (tmp['路線名'] == '関西線'), '駅名'] = '柏原' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '柏原') & (tmp['路線名'] == '福知山線'), '駅名'] = '柏原' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '柏原') & (tmp['路線名'] == '東海道線'), '駅名'] = '柏原' + '_' + '滋賀'

tmp.loc[(tmp['駅名'] == '野崎') & (tmp['路線名'] == '片町線'), '駅名'] = '野崎' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '野崎') & (tmp['路線名'] == '東北線'), '駅名'] = '野崎' + '_' + '栃木'

tmp.loc[(tmp['駅名'] == '神戸') & (tmp['路線名'] == 'わたらせ渓谷線'), '駅名'] = '神戸' + '_' + '群馬'
tmp.loc[(tmp['駅名'] == '神戸') & (tmp['路線名'] == '東海道線'), '駅名'] = '神戸' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '神戸') & (tmp['路線名'] == '渥美線'), '駅名'] = '神戸' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '小林') & (tmp['路線名'] == '吉都線'), '駅名'] = '小林' + '_' + '宮崎'
tmp.loc[(tmp['駅名'] == '小林') & (tmp['路線名'] == '今津線'), '駅名'] = '小林' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '小林') & (tmp['路線名'] == '成田線'), '駅名'] = '小林' + '_' + '千葉'

tmp.loc[(tmp['駅名'] == '多田') & (tmp['路線名'] == '佐野線'), '駅名'] = '多田' + '_' + '栃木'
tmp.loc[(tmp['駅名'] == '多田') & (tmp['路線名'] == '妙見線'), '駅名'] = '多田' + '_' + '兵庫'

tmp.loc[(tmp['駅名'] == '亀山') & (tmp['路線名'] == '本線'), '駅名'] = '亀山' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '亀山') & (tmp['路線名'] == '関西線'), '駅名'] = '亀山' + '_' + '三重'

tmp.loc[(tmp['駅名'] == '横山') & (tmp['路線名'] == '三田線'), '駅名'] = '横山' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '横山') & (tmp['路線名'] == '七尾線'), '駅名'] = '横山' + '_' + '石川'

tmp.loc[(tmp['駅名'] == '広野') & (tmp['路線名'] == '福知山線'), '駅名'] = '広野' + '_' + '兵庫'
tmp.loc[(tmp['駅名'] == '広野') & (tmp['路線名'] == '常磐線'), '駅名'] = '広野' + '_' + '福島'

tmp.loc[(tmp['駅名'] == '東松江') & (tmp['路線名'] == '山陰線'), '駅名'] = '東松江' + '_' + '島根'
tmp.loc[(tmp['駅名'] == '東松江') & (tmp['路線名'] == '加太線'), '駅名'] = '東松江' + '_' + '和歌山'

tmp.loc[(tmp['駅名'] == '神前') & (tmp['路線名'] == '高徳線'), '駅名'] = '神前' + '_' + '香川'
tmp.loc[(tmp['駅名'] == '神前') & (tmp['路線名'] == '貴志川線'), '駅名'] = '神前' + '_' + '和歌山'

tmp.loc[(tmp['駅名'] == '球場前') & (tmp['路線名'] == '水島本線'), '駅名'] = '球場前' + '_' + '岡山'
tmp.loc[(tmp['駅名'] == '球場前') & (tmp['路線名'] == '阿佐線'), '駅名'] = '球場前' + '_' + '高知'

tmp.loc[(tmp['駅名'] == '横川') & (tmp['路線名'] == '山陽線'), '駅名'] = '横川' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '横川') & (tmp['路線名'] == '信越線'), '駅名'] = '横川' + '_' + '群馬'

tmp.loc[(tmp['駅名'] == '西条') & (tmp['路線名'] == '山陽線'), '駅名'] = '西条' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '西条') & (tmp['路線名'] == '篠ノ井線'), '駅名'] = '西条' + '_' + '長野'

tmp.loc[(tmp['駅名'] == '新白島') & (tmp['路線名'] == '山陽線'), '駅名'] = '新白島' + '_' + 'JR'
tmp.loc[(tmp['駅名'] == '新白島') & (tmp['路線名'] == '広島新交通1号線'), '駅名'] = '新白島' + '_' + '広島高速交通'

tmp.loc[(tmp['駅名'] == '西原') & (tmp['路線名'] == '広島新交通1号線'), '駅名'] = '西原' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '西原') & (tmp['路線名'] == '牟岐線'), '駅名'] = '西原' + '_' + '徳島'

tmp.loc[(tmp['駅名'] == '大原') & (tmp['路線名'] == 'いすみ線'), '駅名'] = '大原' + '_' + '千葉'
tmp.loc[(tmp['駅名'] == '大原') & (tmp['路線名'] == '広島新交通1号線'), '駅名'] = '大原' + '_' + '広島'
tmp.loc[(tmp['駅名'] == '大原') & (tmp['路線名'] == '智頭線'), '駅名'] = '大原' + '_' + '岡山'
tmp.loc[(tmp['駅名'] == '大原') & (tmp['路線名'] == '外房線'), '駅名'] = '大原' + '_' + '千葉'

tmp.loc[(tmp['駅名'] == '観音町') & (tmp['路線名'] == '勝山永平寺線'), '駅名'] = '観音町' + '_' + '福井'
tmp.loc[(tmp['駅名'] == '観音町') & (tmp['路線名'] == '本線'), '駅名'] = '観音町' + '_' + '広島'

tmp.loc[(tmp['駅名'] == '東新川') & (tmp['路線名'] == '上毛線'), '駅名'] = '東新川' + '_' + '群馬'
tmp.loc[(tmp['駅名'] == '東新川') & (tmp['路線名'] == '宇部線'), '駅名'] = '東新川' + '_' + '山口'

tmp.loc[(tmp['駅名'] == '片原町') & (tmp['路線名'] == '琴平線'), '駅名'] = '片原町' + '_' + '高松'
tmp.loc[(tmp['駅名'] == '片原町') & (tmp['路線名'] == '高岡軌道線'), '駅名'] = '片原町' + '_' + '富山'

tmp.loc[(tmp['駅名'] == '松山') & (tmp['路線名'] == '予讃線'), '駅名'] = '松山' + '_' + '愛媛'
tmp.loc[(tmp['駅名'] == '松山') & (tmp['路線名'] == '糸田線'), '駅名'] = '松山' + '_' + '福岡'

tmp.loc[(tmp['駅名'] == '旭') & (tmp['路線名'] == '土讃線'), '駅名'] = '旭' + '_' + '高知'
tmp.loc[(tmp['駅名'] == '旭') & (tmp['路線名'] == '総武線'), '駅名'] = '旭' + '_' + '千葉'

tmp.loc[(tmp['駅名'] == '高宮') & (tmp['路線名'] == '本線'), '駅名'] = '高宮' + '_' + '滋賀'
tmp.loc[(tmp['駅名'] == '高宮') & (tmp['路線名'] == '天神大牟田線'), '駅名'] = '高宮' + '_' + '福岡'

tmp.loc[(tmp['駅名'] == '大橋') & (tmp['路線名'] == '天神大牟田線'), '駅名'] = '大橋' + '_' + '福岡'
tmp.loc[(tmp['駅名'] == '大橋') & (tmp['路線名'] == '本線'), '駅名'] = '大橋' + '_' + '長崎'

tmp.loc[(tmp['駅名'] == '荒尾') & (tmp['路線名'] == '鹿児島線'), '駅名'] = '荒尾' + '_' + '熊本'
tmp.loc[(tmp['駅名'] == '荒尾') & (tmp['路線名'] == '東海道線'), '駅名'] = '荒尾' + '_' + '岐阜'

tmp.loc[(tmp['駅名'] == '長崎') & (tmp['路線名'] == '長崎線'), '駅名'] = '長崎' + '_' + '長崎'
tmp.loc[(tmp['駅名'] == '長崎') & (tmp['路線名'] == '後免線'), '駅名'] = '長崎' + '_' + '高知'

tmp.loc[(tmp['駅名'] == '上熊本') & (tmp['路線名'] == '鹿児島線'), '駅名'] = '上熊本' + '_' + 'JR・熊本電鉄'
tmp.loc[(tmp['駅名'] == '上熊本') & (tmp['路線名'] == '上熊本線'), '駅名'] = '上熊本' + '_' + 'JR・熊本電鉄'
tmp.loc[(tmp['駅名'] == '上熊本') & (tmp['路線名'] == '菊池線'), '駅名'] = '上熊本' + '_' + 'JR・熊本電鉄'

tmp.loc[(tmp['駅名'] == '牧') & (tmp['路線名'] == '日豊線'), '駅名'] = '牧' + '_' + '大分'
tmp.loc[(tmp['駅名'] == '牧') & (tmp['路線名'] == '宮福線'), '駅名'] = '牧' + '_' + '京都'

tmp.loc[(tmp['駅名'] == '国分') & (tmp['路線名'] == '日豊線'), '駅名'] = '国分' + '_' + '鹿児島'
tmp.loc[(tmp['駅名'] == '国分') & (tmp['路線名'] == '予讃線'), '駅名'] = '国分' + '_' + '香川'

tmp.loc[(tmp['駅名'] == '郡元') & (tmp['路線名'] == '指宿枕崎線'), '駅名'] = '郡元' + '_' + 'JR'
tmp.loc[(tmp['駅名'] == '郡元') & (tmp['路線名'] == '谷山線'), '駅名'] = '郡元' + '_' + '市電'

tmp.loc[(tmp['駅名'] == '市立病院前') & (tmp['路線名'] == '沖縄都市モノレール線'), '駅名'] = '市立病院前' + '_' + '沖縄'
tmp.loc[(tmp['駅名'] == '市立病院前') & (tmp['路線名'] == '唐湊線'), '駅名'] = '市立病院前' + '_' + '鹿児島'

tmp.loc[(tmp['駅名'] == '千歳町') & (tmp['路線名'] == '本線'), '駅名'] = '千歳町' + '_' + '長崎'
tmp.loc[(tmp['駅名'] == '千歳町') & (tmp['路線名'] == '湯の川線'), '駅名'] = '千歳町' + '_' + '北海道'

# %%
tmp.loc[(tmp['駅名'] == '愛宕') & (tmp['路線名'] == '東北線'), '駅名'] = '愛宕' + '_' + '宮城'
tmp.loc[(tmp['駅名'] == '愛宕') & (tmp['路線名'] == '野田線'), '駅名'] = '愛宕'# + '_' + '千葉'

tmp.loc[(tmp['駅名'] == '東雲') & (tmp['路線名'] == '石北線'), '駅名'] = '東雲' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == '中野') & (tmp['路線名'] == '5号線東西線'), '駅名'] = '中野' + '_' + '東京'

tmp.loc[(tmp['駅名'] == '小川町') & (tmp['路線名'] == '八高線'), '駅名'] = '小川町' + '_' + '埼玉'

tmp.loc[(tmp['駅名'] == '大和') & (tmp['路線名'] == '水戸線'), '駅名'] = '大和' + '_' + '茨城'

tmp.loc[(tmp['駅名'] == '入谷') & (tmp['路線名'] == '2号線日比谷線'), '駅名'] = '入谷' + '_' + '東京'
tmp.loc[(tmp['駅名'] == '入谷') & (tmp['路線名'] == '相模線'), '駅名'] = '入谷' # + '_' + '神奈川'

tmp.loc[(tmp['駅名'] == '長野') & (tmp['路線名'] == '北しなの線'), '駅名'] = '長野' + '_' + 'JR・しなの'

tmp.loc[(tmp['駅名'] == '桐原') & (tmp['路線名'] == '長野線'), '駅名'] = '桐原'# + '_' + '長野'
tmp.loc[(tmp['駅名'] == '桐原') & (tmp['路線名'] == '越後線'), '駅名'] = '桐原' + '_' + '新潟'

tmp.loc[(tmp['駅名'] == '赤池') & (tmp['路線名'] == '豊田線'), '駅名'] = '赤池' + '_' + '愛知'

tmp.loc[(tmp['駅名'] == '桂川') & (tmp['路線名'] == '函館線'), '駅名'] = '桂川' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == '竹田') & (tmp['路線名'] == '京都線'), '駅名'] = '竹田' + '_' + '京都'

tmp.loc[(tmp['駅名'] == '北浜') & (tmp['路線名'] == '釧網線'), '駅名'] = '北浜' + '_' + '北海道'

tmp.loc[(tmp['駅名'] == '中百舌鳥') & (tmp['路線名'] == '泉北高速鉄道線'), '駅名'] = '中百舌鳥' + '_' + '南海・泉北'

tmp.loc[(tmp['駅名'] == '川西') & (tmp['路線名'] == '錦川清流線'), '駅名'] = '川西' + '_' + '山口'

tmp.loc[(tmp['駅名'] == '柏原') & (tmp['路線名'] == '道明寺線'), '駅名'] = '柏原' + '_' + '大阪'

tmp.loc[(tmp['駅名'] == '志井') & (tmp['路線名'] == '日田彦山線'), '駅名'] = '志井' + '_' + 'JR'
tmp.loc[(tmp['駅名'] == '志井') & (tmp['路線名'] == '小倉線'), '駅名'] = '志井' + '_' + '北九州モノレール'

# %%
tmp.loc[(tmp['駅名'] == '星ヶ丘') & (tmp['路線名'] == '交野線'), '駅名'] = '星ヶ丘' + '_' + '大阪'
tmp.loc[(tmp['駅名'] == '星ヶ丘') & (tmp['路線名'] == '1号線東山線'), '駅名'] = '星ヶ丘' + '_' + '愛知'
tmp.loc[(tmp['駅名'] == '松ヶ崎') & (tmp['路線名'] == '烏丸線'), '駅名'] = '松ヶ崎' + '_' + '京都'
tmp.loc[(tmp['駅名'] == '松ヶ崎') & (tmp['路線名'] == '山田線'), '駅名'] = '松ヶ崎' + '_' + '三重'
tmp.loc[(tmp['駅名'] == '霞ヶ丘') & (tmp['路線名'] == '生駒鋼索線'), '駅名'] = '霞ヶ丘' + '_' + '奈良'
tmp.loc[(tmp['駅名'] == '霞ヶ丘') & (tmp['路線名'] == '本線'), '駅名'] = '霞ヶ丘' + '_' + '兵庫'

# %%
stationlist = ['稲荷町']

# %%
for station in stationlist:
    if len(tmp[tmp['駅名'] == station]) > 0:
        # display(tmp[tmp['駅名'] == station])
        for line in  tmp[tmp['駅名'] == station]['路線名']:
            print("tmp.loc[(tmp['駅名'] == '" + station + "') & (tmp['路線名'] == '" + line + "'), '駅名'] = '" + station + "' + '_' + ''")
        print()

# %%
for station in stationlist:
    if '_' in station:
        stationname = station.split('_')[0]
        print("'{}', ".format(station))

# %%
tmp
# Out:
#                  駅名       運営会社         路線名  乗降客数2019
# 0               二月田     九州旅客鉄道       指宿枕崎線       690
# 1                古島  沖縄都市モノレール  沖縄都市モノレール線      5143
# 2           お台場海浜公園      ゆりかもめ  東京臨海新交通臨海線     16899
# 3     東京国際クルーズターミナル      ゆりかもめ  東京臨海新交通臨海線      3191
# 4          テレコムセンター      ゆりかもめ  東京臨海新交通臨海線     12140
# ...             ...        ...         ...       ...
# 9631          てだこ浦西  沖縄都市モノレール  沖縄都市モノレール線      2605
# 9632           浦添前田  沖縄都市モノレール  沖縄都市モノレール線      1088
# 9633             経塚  沖縄都市モノレール  沖縄都市モノレール線      1293
# 9634             石嶺  沖縄都市モノレール  沖縄都市モノレール線      2045
# 9635          ふかや花園       秩父鉄道        秩父本線       161
#
# [9636 rows x 4 columns]

# %%
df_group = tmp.groupby('駅名').sum().reset_index()[['駅名','乗降客数2019']]

# %%
df_group
# Out:
#            駅名  乗降客数2019
# 0       JR三山木      2138
# 1       JR五位堂      1514
# 2       JR俊徳道     10402
# 3        JR小倉      3700
# 4      JR河内永和     17258
# ...       ...       ...
# 9000      龍王峡       100
# 9001   龍谷大前深草      8844
# 9002  ＪＡ広島病院前      1474
# 9003   ＪＲ松山駅前      3961
# 9004    ＹＲＰ野比     18536
#
# [9005 rows x 2 columns]

# %%
df_group.to_csv('reference/passengers.csv', index=False)
